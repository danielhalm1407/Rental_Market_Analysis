# %% [markdown]
# # Clean the Property Data Gathered

# %% [markdown]
# ## Import Packages

# %%
# Web - Scraping and API Requests
import requests
from httpx import AsyncClient, Response
from parsel import Selector
import parsel
import jmespath
import asyncio

# Data Manipulation and Analysis
import pandas as pd
from pprint import pprint 
import json
from typing import List
from typing import TypedDict

# Database Connection
from sqlalchemy import create_engine
from sqlalchemy import inspect, text

# File and System Operations
import os
import sys

# %%
pd.set_option('display.max_columns', None) # Display all columns in any given DataFrame

# %%
# This allows one to reload the custom package without having to install it again
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# this allows one to reload the custom package without having to install it again
# %autoreload 1

sys.path.insert(0,'../src/')

# Import the custom package and sub-packages
# %aimport rental_utils
# %aimport rental_utils.functions
# %aimport rental_utils.sql_queries

# %%
# Load SQL Magic for Jupyter Notebooks
# %load_ext sql
# %config SqlMagic.displaylimit = None
# %config SqlMagic.autocommit=True # for engines that do not support autommit
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# displaylimit: Value None will be treated as 0 (no limit)

# %% [markdown]
# ## Clean the data for selected urls

# %%
with open("../data/rightmove_properties.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
display(data[0])
# Out:
# {'id': 163153346,
#  'bedrooms': 4,
#  'bathrooms': 4,
#  'numberOfImages': 15,
#  'numberOfFloorplans': 1,
#  'numberOfVirtualTours': 0,
#  'summary': 'A spacious four bedroom lateral apartment to rent located near Holland Park. Luxurious and spacious, this exquisite four bedroom lateral apartment offers an unparalleled living experience in this prestigious Kensington block. Boasting elegance and comfort, this residence features: Air conditioni...',
#  'displayAddress': 'Warwick Gardens, London, W14.',
#  'countryCode': 'GB',
#  'location': {'latitude': 51.495757, 'longitude': -0.202902},
#  'propertyImages': {'images': [{'url': '66k/65890/163153346/65890_KEQ012539097_IMG_00_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_00_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_01_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_01_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_02_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_02_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_03_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_03_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_04_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_04_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_05_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_05_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_06_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_06_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_07_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_07_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_08_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_08_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_09_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_09_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_10_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_10_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_11_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_11_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_12_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_12_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_13_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_13_0000_max_476x317.jpeg'},
#    {'url': '66k/65890/163153346/65890_KEQ012539097_IMG_14_0000.jpeg',
#     'caption': None,
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_14_0000_max_476x317.jpeg'}],
#   'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_00_0000_max_476x317.jpeg',
#   'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/66k/65890/163153346/65890_KEQ012539097_IMG_00_0000_max_296x197.jpeg'},
#  'propertySubType': 'Flat',
#  'listingUpdate': {'listingUpdateReason': 'price_reduced',
#   'listingUpdateDate': '2025-04-03T16:16:36Z'},
#  'price': {'amount': 2150,
#   'frequency': 'weekly',
#   'currencyCode': 'GBP',
#   'displayPrices': [{'displayPrice': '£9,317 pcm',
#     'displayPriceQualifier': ''},
#    {'displayPrice': '£2,150 pw', 'displayPriceQualifier': ''}]},
#  'premiumListing': False,
#  'featuredProperty': True,
#  'customer': {'branchId': 65890,
#   'brandPlusLogoURI': '/company/clogo_rmchoice_16112_0017.png',
#   'contactTelephone': '020 3869 5439',
#   'branchDisplayName': 'Knight Frank - Lettings, Kensington',
#   'branchName': 'Kensington',
#   'brandTradingName': 'Knight Frank - Lettings',
#   'branchLandingPageUrl': '/estate-agents/agent/Knight-Frank---Lettings/Kensington-65890.html',
#   'development': False,
#   'showReducedProperties': True,
#   'commercial': False,
#   'showOnMap': True,
#   'enhancedListing': False,
#   'developmentContent': None,
#   'buildToRent': False,
#   'buildToRentBenefits': [],
#   'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/company/clogo_rmchoice_16112_0017.png'},
#  'distance': None,
#  'transactionType': 'rent',
#  'productLabel': {'productLabelText': None, 'spotlightLabel': False},
#  'commercial': False,
#  'development': False,
#  'residential': True,
#  'students': False,
#  'auction': False,
#  'feesApply': True,
#  'feesApplyText': 'Please note that the material information included in this advert is provided to Knight Frank by third parties and is provided here as a guide only. Some of the information provided (such as the rent, deposit or length of tenancy) is subject to change, depending on offers received by the landlord. While Knight Frank has taken steps to verify this information, we advise you to confirm the details of any such material information prior to any offer for the tenancy being submitted. If we are informed of changes to this information by the landlord, we will use all reasonable endeavours to update this as soon as practical.<br /><p>Minimum Tenancy Length</p><p>This is the minimum amount of time the property is available to let on the day the property went on to the market. For more information about the amount of time the property is available for, please speak to a member of our team.</p><p>Tenant charges</p><p>All potential tenants should be advised that, as well as rent a holding deposit will be payable which is equal to one week s rent (if an AST) and two weeks  rent (if not an AST), a tenancy deposit will also be payable which is equal to 6 weeks rent (if not an AST and/or the annual rent is over £50,000), or 5 weeks  rent (if an AST and/or the annual rent is below £50,000). If the landlord agrees to you having a pet you may be required to pay a higher deposit (if not an AST) or higher weekly rent (if an AST).</p><p>You will also be required to pay the following:</p><p>Before the tenancy starts:<br />Deposit (usually equivalent of between five and six weeks&#39; rent dependant on the annual rent)<br />Tenancy Agreement fee (£288 inclusive of VAT) (Non ASTs only)<br />Reference fee payable by each tenant/guarantor (£60 inclusive of VAT) (Non AST only)<br />Bank reference fee (refer to your bank as charges vary) (Non AST only)<br />Stamp Duty (on tenancies that amount to over £125,000)</p><p>During the tenancy:<br />Utilities (gas, electricity, water and telephone)<br />Council Tax<br />Television licence<br />Installation of cable/satellite (if permitted and applicable)<br />Subscription to cable/satellite supplier<br />Insurance (for your personal and own contents)<br />Garden maintenance</p><p>At the end of the tenancy:<br />Cleaning of the property<br />Inventory check-out (Non ASTs only)<br />Dilapidations (as agreed)</p><p>Knight Frank are members of the Property Redress Scheme (Consumer Redress Scheme) and RICS Dispute Resolution Service (Business Redress Scheme) and have Client Money protection with RICS Client Money Protection Scheme.</p><p>Please ask us for more information about other fees that will apply or visit our website.</p>',
#  'displaySize': '213 sq. m.',
#  'showOnMap': True,
#  'propertyUrl': '/properties/163153346#/?channel=RES_LET',
#  'contactUrl': '/property-to-rent/contactBranch.html?propertyId=163153346',
#  'staticMapUrl': None,
#  'channel': 'RENT',
#  'firstVisibleDate': '2025-06-11T12:16:01Z',
#  'keywords': [],
#  'keywordMatchType': 'no_keyword',
#  'saved': False,
#  'hidden': False,
#  'onlineViewingsAvailable': False,
#  'lozengeModel': {'matchingLozenges': []},
#  'hasBrandPlus': True,
#  'displayStatus': '',
#  'enquiredTimestamp': None,
#  'enquiryAddedTimestamp': None,
#  'enquiryCalledTimestamp': None,
#  'heading': 'Featured Property',
#  'isRecent': False,
#  'enhancedListing': False,
#  'addedOrReduced': 'Reduced on 03/04/2025',
#  'formattedBranchName': ' by Knight Frank - Lettings, Kensington',
#  'formattedDistance': '',
#  'propertyTypeFullDescription': '4 bedroom flat'}

# %% [markdown]
# ### Normalise th JSON so that it turns into a dataframe

# %%
data_norm = pd.json_normalize(data, max_level = 1)
data_norm.head(1)
# Out:
#           id  bedrooms  bathrooms  numberOfImages  numberOfFloorplans  \
# 0  163153346         4        4.0              15                   1
#
#    numberOfVirtualTours                                            summary  \
# 0                     0  A spacious four bedroom lateral apartment to r...
#
#                   displayAddress countryCode propertySubType  premiumListing  \
# 0  Warwick Gardens, London, W14.          GB            Flat           False
#
#    featuredProperty distance transactionType  commercial  development  \
# 0              True     None            rent       False        False
#
#    residential  students  auction  feesApply  \
# 0         True     False    False       True
#
#                                        feesApplyText displaySize  showOnMap  \
# 0  Please note that the material information incl...  213 sq. m.       True
#
#                                propertyUrl  \
# 0  /properties/163153346#/?channel=RES_LET
#
#                                           contactUrl staticMapUrl channel  \
# 0  /property-to-rent/contactBranch.html?propertyI...         None    RENT
#
#        firstVisibleDate keywords keywordMatchType  saved  hidden  \
# 0  2025-06-11T12:16:01Z       []       no_keyword  False   False
#
#    onlineViewingsAvailable  hasBrandPlus displayStatus enquiredTimestamp  \
# 0                    False          True                            None
#
#   enquiryAddedTimestamp enquiryCalledTimestamp            heading  isRecent  \
# 0                  None                   None  Featured Property     False
#
#    enhancedListing         addedOrReduced  \
# 0            False  Reduced on 03/04/2025
#
#                        formattedBranchName formattedDistance  \
# 0   by Knight Frank - Lettings, Kensington
#
#   propertyTypeFullDescription  location.latitude  location.longitude  \
# 0              4 bedroom flat          51.495757           -0.202902
#
#                                propertyImages.images  \
# 0  [{'url': '66k/65890/163153346/65890_KEQ0125390...
#
#                          propertyImages.mainImageSrc  \
# 0  https://media.rightmove.co.uk:443/dir/crop/10:...
#
#                       propertyImages.mainMapImageSrc  \
# 0  https://media.rightmove.co.uk:443/dir/crop/10:...
#
#   listingUpdate.listingUpdateReason listingUpdate.listingUpdateDate  \
# 0                     price_reduced            2025-04-03T16:16:36Z
#
#    price.amount price.frequency price.currencyCode  \
# 0          2150          weekly                GBP
#
#                                  price.displayPrices  customer.branchId  \
# 0  [{'displayPrice': '£9,317 pcm', 'displayPriceQ...              65890
#
#                 customer.brandPlusLogoURI customer.contactTelephone  \
# 0  /company/clogo_rmchoice_16112_0017.png             020 3869 5439
#
#             customer.branchDisplayName customer.branchName  \
# 0  Knight Frank - Lettings, Kensington          Kensington
#
#   customer.brandTradingName  \
# 0   Knight Frank - Lettings
#
#                        customer.branchLandingPageUrl  customer.development  \
# 0  /estate-agents/agent/Knight-Frank---Lettings/K...                 False
#
#    customer.showReducedProperties  customer.commercial  customer.showOnMap  \
# 0                            True                False                True
#
#    customer.enhancedListing customer.developmentContent  customer.buildToRent  \
# 0                     False                        None                 False
#
#   customer.buildToRentBenefits  \
# 0                           []
#
#                            customer.brandPlusLogoUrl  \
# 0  https://media.rightmove.co.uk:443/company/clog...
#
#   productLabel.productLabelText  productLabel.spotlightLabel  \
# 0                          None                        False
#
#   lozengeModel.matchingLozenges
# 0                            []

# %% [markdown]
# ### Filter out only the desired columns

# %%
def filter_df(df: pd.DataFrame) -> pd.DataFrame:
    """
    Filters the input DataFrame to retain only the columns relevant for property analysis.

    Args:
        df (pd.DataFrame): The DataFrame to filter.

    Returns:
        pd.DataFrame: A DataFrame containing only the selected columns of interest.
    """
    # Define the list of columns to keep in the filtered DataFrame
    base_cols = [
        'id',
        'bedrooms',
        'bathrooms',
        'numberOfImages',
        'displayAddress',
        'location.latitude',
        'location.longitude',
        'propertySubType',
        'listingUpdate.listingUpdateReason',
        'listingUpdate.listingUpdateDate',
        'price.amount',
        'price.frequency',
        'premiumListing',
        'featuredProperty',
        'transactionType',
        'students',
        'displaySize',
        'propertyUrl',
        'firstVisibleDate',
        'addedOrReduced',
        'propertyTypeFullDescription'
    ]
    # Assign the columns of interest (can be extended or modified if needed)
    columns_of_interest = base_cols
    # Filter the DataFrame to include only the columns of interest
    filtered_df = df[columns_of_interest]
    # Create a price per bedroom column
    filtered_df = filtered_df.copy()
    filtered_df.loc[:, "price_per_bed"] = filtered_df["price.amount"] / filtered_df["bedrooms"]
    # remove rows with a duplicated id
    filtered_df = filtered_df.drop_duplicates(subset="id")
    # Return the filtered DataFrame
    return filtered_df


filtered_df = filter_df(data_norm)
filtered_df.head()
# Out:
#           id  bedrooms  bathrooms  numberOfImages  \
# 0  163153346         4        4.0              15
# 1  164031689         0        1.0              16
# 2  163307378         3        1.0              15
# 3  162735257         2        2.0               9
# 4  161254532         3        1.0               8
#
#                                    displayAddress  location.latitude  \
# 0                   Warwick Gardens, London, W14.          51.495757
# 1  Landmark Pinnacle, 10 Marsh Wall. Canary Wharf          51.502685
# 2                  Forest Hill Road, London, SE22          51.452835
# 3                        Evering Road, London, E5          51.560450
# 4                    Springdale Road, London, N16          51.555540
#
#    location.longitude propertySubType listingUpdate.listingUpdateReason  \
# 0           -0.202902            Flat                     price_reduced
# 1           -0.025471       Apartment                               new
# 2           -0.060605   Semi-Detached                     price_reduced
# 3           -0.062852            Flat                     price_reduced
# 4           -0.087071            Flat                     price_reduced
#
#   listingUpdate.listingUpdateDate  price.amount price.frequency  \
# 0            2025-04-03T16:16:36Z          2150          weekly
# 1            2025-07-01T18:14:03Z           623          weekly
# 2            2025-07-01T18:13:54Z          3600         monthly
# 3            2025-07-01T18:13:50Z          2635         monthly
# 4            2025-07-01T18:13:08Z          3150         monthly
#
#    premiumListing  featuredProperty transactionType  students displaySize  \
# 0           False              True            rent     False  213 sq. m.
# 1           False             False            rent     False   42 sq. m.
# 2           False             False            rent     False
# 3           False             False            rent     False
# 4           False             False            rent     False
#
#                                propertyUrl      firstVisibleDate  \
# 0  /properties/163153346#/?channel=RES_LET  2025-06-11T12:16:01Z
# 1  /properties/164031689#/?channel=RES_LET  2025-07-01T18:08:35Z
# 2  /properties/163307378#/?channel=RES_LET  2025-06-13T16:58:03Z
# 3  /properties/162735257#/?channel=RES_LET  2025-06-02T15:12:55Z
# 4  /properties/161254532#/?channel=RES_LET  2025-04-29T10:23:18Z
#
#           addedOrReduced    propertyTypeFullDescription  price_per_bed
# 0  Reduced on 03/04/2025                 4 bedroom flat          537.5
# 1            Added today               Studio apartment            inf
# 2          Reduced today  3 bedroom semi-detached house         1200.0
# 3          Reduced today                 2 bedroom flat         1317.5
# 4          Reduced today                 3 bedroom flat         1050.0

# %%
filtered_df = rental_utils.functions.filter_df(df=filtered_df)

# %% [markdown]
# ### Define a Function that Cleans Certain Column Names

# %%
def clean_column_names(df: pd.DataFrame) -> pd.DataFrame:
    """
    Renames selected columns of a DataFrame to make them more readable and SQL-friendly.
    Specifically, it replaces nested JSON column names (with dots) with simpler names.
    """
    # Create a mapping of the columns whose names we are changing
    rename_map = {
        "location.latitude": "latitude",
        "location.longitude": "longitude",
        "listingUpdate.listingUpdateReason": "listingUpdateReason",
        "listingUpdate.listingUpdateDate": "listingUpdateDate",
        "price.amount": "priceAmount",
        "price.frequency": "priceFrequency",
    }
    # then, actually rename the columns
    return df.rename(columns=rename_map)

# %%
clean_df = rental_utils.functions.clean_column_names(filtered_df)
#clean_df = clean_column_names(filtered_df)
clean_df.dtypes
# Out:
# id                               int64
# bedrooms                         int64
# bathrooms                      float64
# numberOfImages                   int64
# displayAddress                  object
# latitude                       float64
# longitude                      float64
# propertySubType                 object
# listingUpdateReason             object
# listingUpdateDate               object
# priceAmount                      int64
# priceFrequency                  object
# premiumListing                    bool
# featuredProperty                  bool
# transactionType                 object
# students                          bool
# displaySize                     object
# propertyUrl                     object
# firstVisibleDate                object
# addedOrReduced                  object
# propertyTypeFullDescription     object
# price_per_bed                  float64
# dtype: object

# %% [markdown]
# filtered_df.to_csv("../data/properties.csv")

# %% [markdown]
# ### Create a Database and Save The Data to It

# %% [markdown]
# #### Create the Database if It Has Not Been Already

# %%
# Import as a separate sub-module to reduce the lenght of text
from rental_utils import sql_queries as sqlq

engine = sqlq.get_sql_engine("../data/properties.db")

with engine.connect() as conn:
    pass

# %% [markdown]
# #### Save the Data the Database as A New Table

# %%
## Execute the drop table query if needed (Drop the old table and start a fresh one)
with engine.connect() as connection:
    connection.execute(text(sqlq.DROP_PROPERTIES_TABLE_SQL_QUERY))

## Execute the CREATE TABLE query to create a blank table
with engine.connect() as connection:
    connection.execute(text(sqlq.CREATE_TABLE_SQL_QUERY))

# %%
## Save the dataframe into that table, extending it by default
sqlq.make_table(clean_df, "properties_data", engine)

# %% [markdown]
# ### Check if it can be Extracted OK

# %%
with engine.connect() as connection:
    rightmove_data = pd.read_sql(text(sqlq.GET_PROPERTIES_DATA_SQL_QUERY), connection)
rightmove_data.head()
# Out:
#          id  price_per_bed predicted_price_per_bed travel_time distance  \
# 0  50425854          600.0                    None        None     None
# 1  80209919          246.0                    None        None     None
# 2  82567577          669.0                    None        None     None
# 3  83161844         1275.0                    None        None     None
# 4  86137431          460.0                    None        None     None
#
#    bedrooms  bathrooms  numberOfImages  \
# 0         1        1.0              29
# 1         3        1.0              22
# 2         1        1.0              26
# 3         2        2.0               7
# 4         2        2.0              22
#
#                               displayAddress   latitude  longitude  \
# 0              St. George Wharf, London, SW8  51.486140  -0.125480
# 1                   Dunton Road, London, SE1  51.492600  -0.074660
# 2               Riverlight Quay, London, SW8  51.480250  -0.133930
# 3                 Greyhound Road, London, W6  51.484998  -0.218458
# 4  The Modern, Embassy Gardens, London, SW11  51.481964  -0.130297
#
#   propertySubType listingUpdateReason     listingUpdateDate  priceAmount  \
# 0       Apartment                 new  2025-07-01T15:04:28Z          600
# 1        Terraced                 new  2025-07-01T15:46:11Z          738
# 2       Apartment                 new  2025-07-01T14:57:09Z          669
# 3       Apartment                 new  2025-07-01T15:45:11Z         2550
# 4       Apartment                 new  2025-07-01T17:30:02Z          920
#
#   priceFrequency  premiumListing  featuredProperty transactionType  students  \
# 0         weekly               0                 0            rent         1
# 1         weekly               0                 0            rent         0
# 2         weekly               0                 0            rent         0
# 3        monthly               0                 0            rent         0
# 4         weekly               0                 0            rent         0
#
#   displaySize                             propertyUrl      firstVisibleDate  \
# 0   52 sq. m.  /properties/50425854#/?channel=RES_LET  2017-09-07T14:00:35Z
# 1   70 sq. m.  /properties/80209919#/?channel=RES_LET  2019-03-18T14:08:31Z
# 2   47 sq. m.  /properties/82567577#/?channel=RES_LET  2019-06-13T16:25:32Z
# 3   90 sq. m.  /properties/83161844#/?channel=RES_LET  2019-07-09T02:03:16Z
# 4              /properties/86137431#/?channel=RES_LET  2023-05-17T09:25:04Z
#
#   addedOrReduced propertyTypeFullDescription
# 0    Added today         1 bedroom apartment
# 1    Added today    3 bedroom terraced house
# 2    Added today         1 bedroom apartment
# 3    Added today         2 bedroom apartment
# 4    Added today         2 bedroom apartment
