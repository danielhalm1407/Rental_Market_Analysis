# %% [markdown]
# # Clean the Property Data Gathered

# %% [markdown]
# ## Import Packages

# %%
# Web - Scraping and API Requests
import requests
from httpx import AsyncClient, Response
from parsel import Selector
import parsel
import jmespath
import asyncio

# Data Manipulation and Analysis
import pandas as pd
from pprint import pprint 
import json
from typing import List
from typing import TypedDict

# Database Connection
from sqlalchemy import create_engine
from sqlalchemy import inspect, text

# File and System Operations
import os
import sys

# %%
pd.set_option('display.max_columns', None) # Display all columns in any given DataFrame

# %%
# This allows one to reload the custom package without having to install it again
# %load_ext autoreload

# %%
# this allows one to reload the custom package without having to install it again
# %autoreload 1

sys.path.insert(0,'../src/')

# Import the custom package and sub-packages
# %aimport rental_utils
# %aimport rental_utils.functions
# %aimport rental_utils.sql_queries

# %%
# Load SQL Magic for Jupyter Notebooks
# %load_ext sql
# %config SqlMagic.displaylimit = None
# %config SqlMagic.autocommit=True # for engines that do not support autommit
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %% [markdown]
# ## Clean the data for selected urls

# %%
with open("../data/rightmove_properties.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
display(data[0])
# Out:
# {'id': 163818515,
#  'bedrooms': 5,
#  'bathrooms': 3,
#  'numberOfImages': 24,
#  'numberOfFloorplans': 1,
#  'numberOfVirtualTours': 0,
#  'summary': "A stunning five-bedroom family home located on one of Knightsbridge's most beautiful and private garden squares, SW7. This delightful property boasts two reception rooms, open-plan kitchen, dining /family area, conservatory leading to a private patio garden, study area, master bedroom with en...",
#  'displayAddress': 'Trevor Square, Knightsbridge SW7',
#  'countryCode': 'GB',
#  'location': {'latitude': 51.500536, 'longitude': -0.164367},
#  'propertyImages': {'images': [{'url': '129k/128314/163818515/128314_17896_IMG_00_0000.jpeg',
#     'caption': 'First Floor Receptio',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_00_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_01_0000.jpeg',
#     'caption': 'Raised Ground Floor ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_01_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_02_0000.jpeg',
#     'caption': 'Second Floor Master ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_02_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_03_0000.jpeg',
#     'caption': 'En-suite Bathroom ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_03_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_04_0000.jpeg',
#     'caption': 'Raised Ground Floor ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_04_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_05_0000.jpeg',
#     'caption': 'Reception ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_05_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_06_0000.jpeg',
#     'caption': 'Third Floor Bathroom',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_06_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_07_0000.jpeg',
#     'caption': 'Third Floor Bedroom ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_07_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_08_0000.jpeg',
#     'caption': 'Third Floor Bedroom ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_08_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_09_0000.jpeg',
#     'caption': 'Third Floor Bedroom ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_09_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_10_0000.jpeg',
#     'caption': 'Third Floor Bedroom ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_10_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_11_0000.jpeg',
#     'caption': 'Office',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_11_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_12_0000.jpeg',
#     'caption': 'Master Bedroom  ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_12_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_13_0000.jpeg',
#     'caption': 'Reception ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_13_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_14_0000.jpeg',
#     'caption': 'Dining/Kitchen ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_14_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_15_0000.jpeg',
#     'caption': 'Reception  ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_15_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_16_0000.jpeg',
#     'caption': 'Kitchen',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_16_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_17_0000.jpeg',
#     'caption': 'Reception ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_17_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_18_0000.jpeg',
#     'caption': 'Sitting Area ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_18_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_19_0000.jpeg',
#     'caption': 'Exterior',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_19_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_20_0000.jpeg',
#     'caption': 'Patio Garden ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_20_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_21_0000.jpeg',
#     'caption': 'Exterior ',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_21_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_22_0000.jpeg',
#     'caption': 'Communal Garden',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_22_0000_max_476x317.jpeg'},
#    {'url': '129k/128314/163818515/128314_17896_IMG_23_0000.jpeg',
#     'caption': 'Communal Garden',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_23_0000_max_476x317.jpeg'}],
#   'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_00_0000_max_476x317.jpeg',
#   'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/129k/128314/163818515/128314_17896_IMG_00_0000_max_296x197.jpeg'},
#  'propertySubType': 'House',
#  'listingUpdate': {'listingUpdateReason': 'new',
#   'listingUpdateDate': '2025-06-26T10:42:04Z'},
#  'price': {'amount': 2750,
#   'frequency': 'weekly',
#   'currencyCode': 'GBP',
#   'displayPrices': [{'displayPrice': '£11,917 pcm',
#     'displayPriceQualifier': ''},
#    {'displayPrice': '£2,750 pw', 'displayPriceQualifier': ''}]},
#  'premiumListing': False,
#  'featuredProperty': True,
#  'customer': {'branchId': 128314,
#   'brandPlusLogoURI': '/company/clogo_32153_0000.jpg',
#   'contactTelephone': '020 3835 4312',
#   'branchDisplayName': 'Farrar & Co, Chelsea - Lettings',
#   'branchName': 'Chelsea - Lettings',
#   'brandTradingName': 'Farrar & Co',
#   'branchLandingPageUrl': '/estate-agents/agent/Farrar-and-Co/Chelsea---Lettings-128314.html',
#   'development': False,
#   'showReducedProperties': True,
#   'commercial': False,
#   'showOnMap': True,
#   'enhancedListing': False,
#   'developmentContent': None,
#   'buildToRent': False,
#   'buildToRentBenefits': [],
#   'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/company/clogo_32153_0000.jpg'},
#  'distance': None,
#  'transactionType': 'rent',
#  'productLabel': {'productLabelText': None, 'spotlightLabel': False},
#  'commercial': False,
#  'development': False,
#  'residential': True,
#  'students': False,
#  'auction': False,
#  'feesApply': True,
#  'feesApplyText': 'Permitted payments and tenant protection information\nPermitted payments \nFor properties in England, the Tenant Fees Act 2019 means that in addition to rent, lettings agents can only charge tenants (or anyone acting on the tenant&#39;s behalf) the following permitted payments: \n \tHolding deposits (a maximum of 1 week&#39;s rent);\n \tDeposits (a maximum deposit of 5 weeks&#39; rent for annual rent below £50,000, or 6 weeks&#39; rent for annual rental of £50,000 and above);\n \tPayments to change a tenancy agreement eg. change of sharer (capped at £50 or, if higher, any reasonable costs);\n \tPayments associated with early termination of a tenancy (capped at the landlord&#39;s loss or the agent&#39;s reasonably incurred costs);\n \tUtilities, communication services (eg. telephone, broadband), TV licence and council tax;\n \tInterest payments for the late payment of rent (up to 3% above Bank of England&#39;s annual percentage rate);\n \tReasonable costs for replacement of lost keys or other security devices;\n \tContractual damages in the event of the tenant&#39;s default of a tenancy agreement; and\n \tAny other permitted payments under the Tenant Fees Act 2019.\n\nFor properties in Wales, the Renting Homes (Fees etc.) (Wales) Bill , once enacted, means that in addition to rent, lettings agents can only charge tenants (or anyone acting on the tenant&#39;s behalf) the following permitted payments: \n \tHolding deposits (a maximum of 1 week&#39;s rent);\n \tDeposits;\n \tUtilities, communication services (eg. telephone, broadband), TV licence and council tax;\n \tPayments for the late payment of rent;\n \tA breach of a term of the contract;\n \tAny other permitted payments under the Renting Homes (Fees etc.) (Wales) Bill and regulations once enacted.\n\nTenant protection \n \tFarrar & Co is a member of the redress scheme operated by the Property Ombudsman.',
#  'displaySize': '',
#  'showOnMap': True,
#  'propertyUrl': '/properties/163818515#/?channel=RES_LET',
#  'contactUrl': '/property-to-rent/contactBranch.html?propertyId=163818515',
#  'staticMapUrl': None,
#  'channel': 'RENT',
#  'firstVisibleDate': '2025-06-26T10:36:08Z',
#  'keywords': [],
#  'keywordMatchType': 'no_keyword',
#  'saved': False,
#  'hidden': False,
#  'onlineViewingsAvailable': False,
#  'lozengeModel': {'matchingLozenges': []},
#  'hasBrandPlus': True,
#  'displayStatus': '',
#  'enquiredTimestamp': None,
#  'enquiryAddedTimestamp': None,
#  'enquiryCalledTimestamp': None,
#  'heading': 'Featured Property',
#  'isRecent': False,
#  'enhancedListing': False,
#  'addedOrReduced': 'Added on 26/06/2025',
#  'formattedBranchName': ' by Farrar & Co, Chelsea - Lettings',
#  'formattedDistance': '',
#  'propertyTypeFullDescription': '5 bedroom house'}

# %% [markdown]
# ### Normalise th JSON so that it turns into a dataframe

# %%
data_norm = pd.json_normalize(data, max_level = 1)
data_norm.head(1)
# Out:
#           id  bedrooms  bathrooms  numberOfImages  numberOfFloorplans  \
# 0  163818515         5          3              24                   1
#
#    numberOfVirtualTours                                            summary  \
# 0                     0  A stunning five-bedroom family home located on...
#
#                      displayAddress countryCode propertySubType  \
# 0  Trevor Square, Knightsbridge SW7          GB           House
#
#    premiumListing  featuredProperty distance transactionType  commercial  \
# 0           False              True     None            rent       False
#
#    development  residential  students  auction  feesApply  \
# 0        False         True     False    False       True
#
#                                        feesApplyText displaySize  showOnMap  \
# 0  Permitted payments and tenant protection infor...                   True
#
#                                propertyUrl  \
# 0  /properties/163818515#/?channel=RES_LET
#
#                                           contactUrl staticMapUrl channel  \
# 0  /property-to-rent/contactBranch.html?propertyI...         None    RENT
#
#        firstVisibleDate keywords keywordMatchType  saved  hidden  \
# 0  2025-06-26T10:36:08Z       []       no_keyword  False   False
#
#    onlineViewingsAvailable  hasBrandPlus displayStatus enquiredTimestamp  \
# 0                    False          True                            None
#
#   enquiryAddedTimestamp enquiryCalledTimestamp            heading  isRecent  \
# 0                  None                   None  Featured Property     False
#
#    enhancedListing       addedOrReduced                  formattedBranchName  \
# 0            False  Added on 26/06/2025   by Farrar & Co, Chelsea - Lettings
#
#   formattedDistance propertyTypeFullDescription  location.latitude  \
# 0                               5 bedroom house          51.500536
#
#    location.longitude                              propertyImages.images  \
# 0           -0.164367  [{'url': '129k/128314/163818515/128314_17896_I...
#
#                          propertyImages.mainImageSrc  \
# 0  https://media.rightmove.co.uk:443/dir/crop/10:...
#
#                       propertyImages.mainMapImageSrc  \
# 0  https://media.rightmove.co.uk:443/dir/crop/10:...
#
#   listingUpdate.listingUpdateReason listingUpdate.listingUpdateDate  \
# 0                               new            2025-06-26T10:42:04Z
#
#    price.amount price.frequency price.currencyCode  \
# 0          2750          weekly                GBP
#
#                                  price.displayPrices  customer.branchId  \
# 0  [{'displayPrice': '£11,917 pcm', 'displayPrice...             128314
#
#        customer.brandPlusLogoURI customer.contactTelephone  \
# 0  /company/clogo_32153_0000.jpg             020 3835 4312
#
#         customer.branchDisplayName customer.branchName  \
# 0  Farrar & Co, Chelsea - Lettings  Chelsea - Lettings
#
#   customer.brandTradingName  \
# 0               Farrar & Co
#
#                        customer.branchLandingPageUrl  customer.development  \
# 0  /estate-agents/agent/Farrar-and-Co/Chelsea---L...                 False
#
#    customer.showReducedProperties  customer.commercial  customer.showOnMap  \
# 0                            True                False                True
#
#    customer.enhancedListing customer.developmentContent  customer.buildToRent  \
# 0                     False                        None                 False
#
#   customer.buildToRentBenefits  \
# 0                           []
#
#                            customer.brandPlusLogoUrl  \
# 0  https://media.rightmove.co.uk:443/company/clog...
#
#   productLabel.productLabelText  productLabel.spotlightLabel  \
# 0                          None                        False
#
#   lozengeModel.matchingLozenges
# 0                            []

# %% [markdown]
# ### Filter out only the desired columns

# %%
def filter_df(df: pd.DataFrame) -> pd.DataFrame:
    """
    Filters the input DataFrame to retain only the columns relevant for property analysis.

    Args:
        df (pd.DataFrame): The DataFrame to filter.

    Returns:
        pd.DataFrame: A DataFrame containing only the selected columns of interest.
    """
    # Define the list of columns to keep in the filtered DataFrame
    base_cols = [
        'id',
        'bedrooms',
        'bathrooms',
        'numberOfImages',
        'displayAddress',
        'location.latitude',
        'location.longitude',
        'propertySubType',
        'listingUpdate.listingUpdateReason',
        'listingUpdate.listingUpdateDate',
        'price.amount',
        'price.frequency',
        'premiumListing',
        'featuredProperty',
        'transactionType',
        'students',
        'displaySize',
        'propertyUrl',
        'firstVisibleDate',
        'addedOrReduced',
        'propertyTypeFullDescription'
    ]
    # Assign the columns of interest (can be extended or modified if needed)
    columns_of_interest = base_cols
    # Filter the DataFrame to include only the columns of interest
    filtered_df = df[columns_of_interest]
    # Create a price per bedroom column
    filtered_df = filtered_df.copy()
    filtered_df.loc[:, "price_per_bed"] = filtered_df["price.amount"] / filtered_df["bedrooms"]
    # Return the filtered DataFrame
    return filtered_df


filtered_df = filter_df(data_norm)
filtered_df.head()
# Out:
#           id  bedrooms  bathrooms  numberOfImages  \
# 0  163818515         5          3              24
# 1  163977209         2          2               9
# 2  163977203         2          1              13
# 3  163977179         1          1               5
# 4  163977128         3          2              13
#
#                      displayAddress  location.latitude  location.longitude  \
# 0  Trevor Square, Knightsbridge SW7          51.500536           -0.164367
# 1                Anson Road, London          51.555435           -0.128682
# 2         Tufnell Park Road, London          51.557703           -0.127115
# 3        Elm Grove Road, London, W5          51.506504           -0.297362
# 4         Montpelier Road, Finchley          51.599838           -0.180289
#
#   propertySubType listingUpdate.listingUpdateReason  \
# 0           House                               new
# 1            Flat                               new
# 2            Flat                               new
# 3      Flat Share                               new
# 4        Terraced                               new
#
#   listingUpdate.listingUpdateDate  price.amount price.frequency  \
# 0            2025-06-26T10:42:04Z          2750          weekly
# 1            2025-06-30T16:41:03Z          2600         monthly
# 2            2025-06-30T16:41:03Z          2400         monthly
# 3            2025-06-30T16:40:04Z           950         monthly
# 4            2025-06-30T16:40:01Z          2850         monthly
#
#    premiumListing  featuredProperty transactionType  students displaySize  \
# 0           False              True            rent     False
# 1           False             False            rent     False
# 2           False             False            rent     False
# 3           False             False            rent     False
# 4           False             False            rent     False
#
#                                propertyUrl      firstVisibleDate  \
# 0  /properties/163818515#/?channel=RES_LET  2025-06-26T10:36:08Z
# 1  /properties/163977209#/?channel=RES_LET  2025-06-30T16:35:10Z
# 2  /properties/163977203#/?channel=RES_LET  2025-06-30T16:35:09Z
# 3  /properties/163977179#/?channel=RES_LET  2025-06-30T16:34:56Z
# 4  /properties/163977128#/?channel=RES_LET  2025-06-30T16:34:04Z
#
#         addedOrReduced propertyTypeFullDescription  price_per_bed
# 0  Added on 26/06/2025             5 bedroom house          550.0
# 1          Added today              2 bedroom flat         1300.0
# 2          Added today              2 bedroom flat         1200.0
# 3          Added today        1 bedroom flat share          950.0
# 4          Added today    3 bedroom terraced house          950.0

# %%
filtered_df = rental_utils.functions.filter_df(df=filtered_df)

# %% [markdown]
# ### Define a Function that Cleans Certain Column Names

# %%
def clean_column_names(df: pd.DataFrame) -> pd.DataFrame:
    """
    Renames selected columns of a DataFrame to make them more readable and SQL-friendly.
    Specifically, it replaces nested JSON column names (with dots) with simpler names.
    """
    # Create a mapping of the columns whose names we are changing
    rename_map = {
        "location.latitude": "latitude",
        "location.longitude": "longitude",
        "listingUpdate.listingUpdateReason": "listingUpdateReason",
        "listingUpdate.listingUpdateDate": "listingUpdateDate",
        "price.amount": "priceAmount",
        "price.frequency": "priceFrequency",
    }
    # then, actually rename the columns
    return df.rename(columns=rename_map)

# %%
clean_df = rental_utils.functions.clean_column_names(filtered_df)
#clean_df = clean_column_names(filtered_df)
clean_df.dtypes
# Out:
# id                               int64
# bedrooms                         int64
# bathrooms                        int64
# numberOfImages                   int64
# displayAddress                  object
# latitude                       float64
# longitude                      float64
# propertySubType                 object
# listingUpdateReason             object
# listingUpdateDate               object
# priceAmount                      int64
# priceFrequency                  object
# premiumListing                    bool
# featuredProperty                  bool
# transactionType                 object
# students                          bool
# displaySize                     object
# propertyUrl                     object
# firstVisibleDate                object
# addedOrReduced                  object
# propertyTypeFullDescription     object
# price_per_bed                  float64
# dtype: object

# %% [markdown]
# filtered_df.to_csv("../data/properties.csv")

# %% [markdown]
# ### Create a Database and Save The Data to It

# %% [markdown]
# #### Create the Database if It Has Not Been Already

# %%
# Import as a separate sub-module to reduce the lenght of text
from rental_utils import sql_queries as sqlq

engine = sqlq.get_sql_engine("../data/properties.db")

with engine.connect() as conn:
    pass

# %% [markdown]
# #### Save the Data the Database as A New Table

# %%
## Execute the drop table query (Drop the old table and start a fresh one)
with engine.connect() as connection:
    connection.execute(text(sqlq.DROP_PROPERTIES_TABLE_SQL_QUERY))

## Execute the CREATE TABLE query to create a blank table
with engine.connect() as connection:
    connection.execute(text(sqlq.CREATE_TABLE_SQL_QUERY))

## Save the dataframe into that table, extending it by default
sqlq.make_table(clean_df, "properties_data", engine)

# %% [markdown]
# ### Check if it can be Extracted OK

# %%
with engine.connect() as connection:
    rightmove_data = pd.read_sql(text(sqlq.GET_PROPERTIES_DATA_SQL_QUERY), connection)
rightmove_data.head()
# Out:
#           id  price_per_bed travel_time distance  bedrooms  bathrooms  \
# 0  161782598    1150.000000        None     None         2          2
# 1  161786591     766.666667        None     None         3          2
# 2  162252746     346.000000        None     None         2          1
# 3  162753398     800.000000        None     None         3          1
# 4  163298408    1025.000000        None     None         2          3
#
#    numberOfImages                       displayAddress   latitude  longitude  \
# 0              10     Martello Street, Hackney, London  51.542839  -0.057569
# 1              12      Penrhyn Avenue, London, E17 5BJ  51.598030  -0.020891
# 2               4  Long Street, London, Shoredtich, E2  51.529050  -0.076430
# 3              12              Folkestone Road, London  51.585121  -0.016140
# 4               7                   Hoptree Close, N12  51.617380  -0.185520
#
#   propertySubType listingUpdateReason     listingUpdateDate  priceAmount  \
# 0            Flat       price_reduced  2025-06-30T16:34:40Z         2300
# 1  End of Terrace       price_reduced  2025-06-30T16:35:49Z         2300
# 2       Apartment       price_reduced  2025-06-30T16:35:02Z          692
# 3            Flat       price_reduced  2025-06-30T16:36:12Z         2400
# 4            Flat       price_reduced  2025-06-30T16:35:11Z         2050
#
#   priceFrequency  premiumListing  featuredProperty transactionType  students  \
# 0        monthly               0                 0            rent         0
# 1        monthly               1                 0            rent         0
# 2         weekly               0                 0            rent         0
# 3        monthly               1                 0            rent         0
# 4        monthly               0                 0            rent         0
#
#   displaySize                              propertyUrl      firstVisibleDate  \
# 0   65 sq. m.  /properties/161782598#/?channel=RES_LET  2025-05-10T13:15:57Z
# 1   90 sq. m.  /properties/161786591#/?channel=RES_LET  2025-05-10T16:30:55Z
# 2              /properties/162252746#/?channel=RES_LET  2025-05-21T15:30:03Z
# 3   80 sq. m.  /properties/162753398#/?channel=RES_LET  2025-06-02T20:53:51Z
# 4              /properties/163298408#/?channel=RES_LET  2025-06-13T15:34:39Z
#
#   addedOrReduced     propertyTypeFullDescription
# 0  Reduced today                  2 bedroom flat
# 1  Reduced today  3 bedroom end of terrace house
# 2  Reduced today             2 bedroom apartment
# 3  Reduced today                  3 bedroom flat
# 4  Reduced today                  2 bedroom flat
