# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
ishares_semi = yf.Ticker("SOXX")

# get historical market data
soxx = ishares_semi.history(period="max")
soxx = soxx.reset_index()

# %%
soxx
# Out:
#                           Date        Open        High         Low  \
# 0    2001-07-13 00:00:00-04:00   19.982121   20.338649   19.506751
# 1    2001-07-16 00:00:00-04:00   19.719567   19.774844   18.915308
# 2    2001-07-17 00:00:00-04:00   18.779879   19.691927   18.766061
# 3    2001-07-18 00:00:00-04:00   19.097718   19.238671   18.876616
# 4    2001-07-19 00:00:00-04:00   20.009754   20.092667   19.678101
# ...                        ...         ...         ...         ...
# 5834 2024-09-23 00:00:00-04:00  224.204095  225.002155  222.408464
# 5835 2024-09-24 00:00:00-04:00  225.999726  228.074675  223.425990
# 5836 2024-09-25 00:00:00-04:00  225.979996  229.770004  225.850006
# 5837 2024-09-26 00:00:00-04:00  237.720001  238.380005  230.289993
# 5838 2024-09-27 00:00:00-04:00  237.149994  237.179993  231.470001
#
#            Close   Volume  Dividends  Stock Splits  Capital Gains
# 0      20.078854   603300      0.000           0.0            0.0
# 1      18.915308   180000      0.000           0.0            0.0
# 2      19.691927   287100      0.000           0.0            0.0
# 3      18.876616   301800      0.000           0.0            0.0
# 4      19.678101   405000      0.000           0.0            0.0
# ...          ...      ...        ...           ...            ...
# 5834  223.994598  2454200      0.000           0.0            0.0
# 5835  226.707993  4314700      0.000           0.0            0.0
# 5836  228.270004  2191200      0.552           0.0            0.0
# 5837  236.429993  5537400      0.000           0.0            0.0
# 5838  232.679993  2288700      0.000           0.0            0.0
#
# [5839 rows x 9 columns]
