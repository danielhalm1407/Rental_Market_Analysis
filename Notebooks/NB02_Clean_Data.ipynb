# %% [markdown]
# # Clean the Property Data Gathered

# %% [markdown]
# ## Import Packages

# %%
# Web - Scraping and API Requests
import requests
from httpx import AsyncClient, Response
from parsel import Selector
import parsel
import jmespath
import asyncio

# Data Manipulation and Analysis
import pandas as pd
from pprint import pprint 
import json
from typing import List
from typing import TypedDict

# Database Connection
from sqlalchemy import create_engine

# File and System Operations
import os
import sys

# %%
pd.set_option('display.max_columns', None) # Display all columns in any given DataFrame

# %%
# This allows one to reload the custom package without having to install it again
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# this allows one to reload the custom package without having to install it again
# %autoreload 1

sys.path.insert(0,'../src/')

# https://stackoverflow.com/questions/70898150/jupyter-autoreload-workflow/73623267#73623267
# My custom package
# %aimport rental_utils

# %%
# Load SQL Magic for Jupyter Notebooks
# %load_ext sql
# %config SqlMagic.displaylimit = None
# %config SqlMagic.autocommit=True # for engines that do not support autommit
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# displaylimit: Value None will be treated as 0 (no limit)

# %% [markdown]
# ## Clean the data for selected urls

# %%
with open("../data/rightmove_properties.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
display(data[0])
# Out:
# {'id': 163628153,
#  'bedrooms': 0,
#  'bathrooms': 1,
#  'numberOfImages': 10,
#  'numberOfFloorplans': 0,
#  'numberOfVirtualTours': 0,
#  'summary': 'A quirky studio apartment situated on the raised ground floor of a stucco fronted period house. The propery benefits from having high ceilings throughout, open plan kitchen, mezzanine sleeping area and a three piece shower room. Available immediately offered furnished. Rent includes all utilities...',
#  'displayAddress': 'Belsize Park, London, NW3',
#  'countryCode': 'GB',
#  'location': {'latitude': 51.548427, 'longitude': -0.171794},
#  'propertyImages': {'images': [{'url': '107k/106225/163628153/106225_BEP210149_L_IMG_00_0000.jpeg',
#     'caption': 'Picture No. 01',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_00_0000_max_476x317.jpeg'},
#    {'url': '107k/106225/163628153/106225_BEP210149_L_IMG_01_0000.jpeg',
#     'caption': 'Picture No. 10',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_01_0000_max_476x317.jpeg'},
#    {'url': '107k/106225/163628153/106225_BEP210149_L_IMG_02_0000.jpeg',
#     'caption': 'Picture No. 02',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_02_0000_max_476x317.jpeg'},
#    {'url': '107k/106225/163628153/106225_BEP210149_L_IMG_03_0000.jpeg',
#     'caption': 'Picture No. 03',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_03_0000_max_476x317.jpeg'},
#    {'url': '107k/106225/163628153/106225_BEP210149_L_IMG_04_0000.jpeg',
#     'caption': 'Picture No. 04',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_04_0000_max_476x317.jpeg'},
#    {'url': '107k/106225/163628153/106225_BEP210149_L_IMG_05_0000.jpeg',
#     'caption': 'Picture No. 05',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_05_0000_max_476x317.jpeg'},
#    {'url': '107k/106225/163628153/106225_BEP210149_L_IMG_06_0000.jpeg',
#     'caption': 'Picture No. 06',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_06_0000_max_476x317.jpeg'},
#    {'url': '107k/106225/163628153/106225_BEP210149_L_IMG_07_0000.jpeg',
#     'caption': 'Picture No. 07',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_07_0000_max_476x317.jpeg'},
#    {'url': '107k/106225/163628153/106225_BEP210149_L_IMG_08_0000.jpeg',
#     'caption': 'Picture No. 08',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_08_0000_max_476x317.jpeg'},
#    {'url': '107k/106225/163628153/106225_BEP210149_L_IMG_09_0000.jpeg',
#     'caption': 'Picture No. 09',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_09_0000_max_476x317.jpeg'}],
#   'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_00_0000_max_476x317.jpeg',
#   'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/107k/106225/163628153/106225_BEP210149_L_IMG_00_0000_max_296x197.jpeg'},
#  'propertySubType': 'Apartment',
#  'listingUpdate': {'listingUpdateReason': 'new',
#   'listingUpdateDate': '2025-06-21T11:06:13Z'},
#  'price': {'amount': 1500,
#   'frequency': 'monthly',
#   'currencyCode': 'GBP',
#   'displayPrices': [{'displayPrice': '£1,500 pcm',
#     'displayPriceQualifier': ''},
#    {'displayPrice': '£346 pw', 'displayPriceQualifier': ''}]},
#  'premiumListing': False,
#  'featuredProperty': True,
#  'customer': {'branchId': 106225,
#   'brandPlusLogoURI': '/company/clogo_19244_0005.jpeg',
#   'contactTelephone': '020 3909 6480',
#   'branchDisplayName': 'Stones Residential, Belsize Park',
#   'branchName': 'Belsize Park',
#   'brandTradingName': 'Stones Residential',
#   'branchLandingPageUrl': '/estate-agents/agent/Stones-Residential/Belsize-Park-106225.html',
#   'development': False,
#   'showReducedProperties': True,
#   'commercial': False,
#   'showOnMap': True,
#   'enhancedListing': False,
#   'developmentContent': None,
#   'buildToRent': False,
#   'buildToRentBenefits': [],
#   'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/company/clogo_19244_0005.jpeg'},
#  'distance': None,
#  'transactionType': 'rent',
#  'productLabel': {'productLabelText': None, 'spotlightLabel': False},
#  'commercial': False,
#  'development': False,
#  'residential': True,
#  'students': False,
#  'auction': False,
#  'feesApply': True,
#  'feesApplyText': None,
#  'displaySize': '',
#  'showOnMap': True,
#  'propertyUrl': '/properties/163628153#/?channel=RES_LET',
#  'contactUrl': '/property-to-rent/contactBranch.html?propertyId=163628153',
#  'staticMapUrl': None,
#  'channel': 'RENT',
#  'firstVisibleDate': '2025-06-21T11:00:44Z',
#  'keywords': [],
#  'keywordMatchType': 'no_keyword',
#  'saved': False,
#  'hidden': False,
#  'onlineViewingsAvailable': False,
#  'lozengeModel': {'matchingLozenges': []},
#  'hasBrandPlus': True,
#  'displayStatus': '',
#  'enquiredTimestamp': None,
#  'enquiryAddedTimestamp': None,
#  'enquiryCalledTimestamp': None,
#  'heading': 'Featured Property',
#  'isRecent': False,
#  'enhancedListing': False,
#  'addedOrReduced': 'Added on 21/06/2025',
#  'formattedBranchName': ' by Stones Residential, Belsize Park',
#  'formattedDistance': '',
#  'propertyTypeFullDescription': 'Studio apartment'}

# %% [markdown]
# ### Normalise th JSON so that it turns into a dataframe

# %%
data_norm = pd.json_normalize(data, max_level = 1)
data_norm.head(1)
# Out:
#           id  bedrooms  bathrooms  numberOfImages  numberOfFloorplans  \
# 0  163628153         0          1              10                   0
#
#    numberOfVirtualTours                                            summary  \
# 0                     0  A quirky studio apartment situated on the rais...
#
#               displayAddress countryCode propertySubType  premiumListing  \
# 0  Belsize Park, London, NW3          GB       Apartment           False
#
#    featuredProperty distance transactionType  commercial  development  \
# 0              True     None            rent       False        False
#
#    residential  students  auction  feesApply feesApplyText displaySize  \
# 0         True     False    False       True          None
#
#    showOnMap                              propertyUrl  \
# 0       True  /properties/163628153#/?channel=RES_LET
#
#                                           contactUrl staticMapUrl channel  \
# 0  /property-to-rent/contactBranch.html?propertyI...         None    RENT
#
#        firstVisibleDate keywords keywordMatchType  saved  hidden  \
# 0  2025-06-21T11:00:44Z       []       no_keyword  False   False
#
#    onlineViewingsAvailable  hasBrandPlus displayStatus enquiredTimestamp  \
# 0                    False          True                            None
#
#   enquiryAddedTimestamp enquiryCalledTimestamp            heading  isRecent  \
# 0                  None                   None  Featured Property     False
#
#    enhancedListing       addedOrReduced                   formattedBranchName  \
# 0            False  Added on 21/06/2025   by Stones Residential, Belsize Park
#
#   formattedDistance propertyTypeFullDescription  location.latitude  \
# 0                              Studio apartment          51.548427
#
#    location.longitude                              propertyImages.images  \
# 0           -0.171794  [{'url': '107k/106225/163628153/106225_BEP2101...
#
#                          propertyImages.mainImageSrc  \
# 0  https://media.rightmove.co.uk:443/dir/crop/10:...
#
#                       propertyImages.mainMapImageSrc  \
# 0  https://media.rightmove.co.uk:443/dir/crop/10:...
#
#   listingUpdate.listingUpdateReason listingUpdate.listingUpdateDate  \
# 0                               new            2025-06-21T11:06:13Z
#
#    price.amount price.frequency price.currencyCode  \
# 0          1500         monthly                GBP
#
#                                  price.displayPrices  customer.branchId  \
# 0  [{'displayPrice': '£1,500 pcm', 'displayPriceQ...             106225
#
#         customer.brandPlusLogoURI customer.contactTelephone  \
# 0  /company/clogo_19244_0005.jpeg             020 3909 6480
#
#          customer.branchDisplayName customer.branchName  \
# 0  Stones Residential, Belsize Park        Belsize Park
#
#   customer.brandTradingName  \
# 0        Stones Residential
#
#                        customer.branchLandingPageUrl  customer.development  \
# 0  /estate-agents/agent/Stones-Residential/Belsiz...                 False
#
#    customer.showReducedProperties  customer.commercial  customer.showOnMap  \
# 0                            True                False                True
#
#    customer.enhancedListing customer.developmentContent  customer.buildToRent  \
# 0                     False                        None                 False
#
#   customer.buildToRentBenefits  \
# 0                           []
#
#                            customer.brandPlusLogoUrl  \
# 0  https://media.rightmove.co.uk:443/company/clog...
#
#   productLabel.productLabelText  productLabel.spotlightLabel  \
# 0                          None                        False
#
#   lozengeModel.matchingLozenges
# 0                            []

# %% [markdown]
# ### Filter out only the desired columns

# %%
def filter_df(df=data_norm):
    base_cols = [
        'id',
        'bedrooms',
        'bathrooms',
        'numberOfImages',
        'displayAddress',
        'location.latitude',
        'location.longitude',
        'propertySubType',
        'listingUpdate.listingUpdateReason',
        'listingUpdate.listingUpdateDate',
        'price.amount',
        'price.frequency',
        'premiumListing',
        'featuredProperty',
        'transactionType',
        'students',
        'displaySize',
        'propertyUrl',
        'firstVisibleDate',
        'addedOrReduced',
        'propertyTypeFullDescription'
    ]
    columns_of_interest = base_cols
    filtered_df = df[columns_of_interest]
    return filtered_df


filtered_df = filter_df(data_norm)
filtered_df.head()
# Out:
#           id  bedrooms  bathrooms  numberOfImages  \
# 0  163628153         0          1              10
# 1  163931060         1          1              10
# 2  163930976         4          2              11
# 3  162597587         1          1              15
# 4  163930820         1          1               7
#
#                                       displayAddress  location.latitude  \
# 0                          Belsize Park, London, NW3          51.548427
# 1  Ravensbury Court, Bishopsford Road, Morden, Lo...          51.389634
# 2                      Queens Road, Walthamstow, E17          51.576702
# 3                        Nine Elms Lane, London, SW8          51.484241
# 4  Brooklands Court, Cavendish Road, Brondesbury,...          51.544548
#
#    location.longitude propertySubType listingUpdate.listingUpdateReason  \
# 0           -0.171794       Apartment                               new
# 1           -0.196730            Flat                               new
# 2           -0.028471  End of Terrace                               new
# 3           -0.127580            Flat                     price_reduced
# 4           -0.204789       Apartment                               new
#
#   listingUpdate.listingUpdateDate  price.amount price.frequency  \
# 0            2025-06-21T11:06:13Z          1500         monthly
# 1            2025-06-28T19:35:01Z          1300         monthly
# 2            2025-06-28T19:14:03Z          4350         monthly
# 3            2025-06-28T19:12:16Z          4000         monthly
# 4            2025-06-28T18:34:04Z           380          weekly
#
#    premiumListing  featuredProperty transactionType  students displaySize  \
# 0           False              True            rent     False
# 1           False             False            rent     False
# 2           False             False            rent     False
# 3           False             False            rent     False
# 4           False             False            rent     False   47 sq. m.
#
#                                propertyUrl      firstVisibleDate  \
# 0  /properties/163628153#/?channel=RES_LET  2025-06-21T11:00:44Z
# 1  /properties/163931060#/?channel=RES_LET  2025-06-28T19:29:09Z
# 2  /properties/163930976#/?channel=RES_LET  2025-06-28T19:08:16Z
# 3  /properties/162597587#/?channel=RES_LET  2025-05-29T17:21:19Z
# 4  /properties/163930820#/?channel=RES_LET  2025-06-28T18:28:54Z
#
#         addedOrReduced     propertyTypeFullDescription
# 0  Added on 21/06/2025                Studio apartment
# 1          Added today                  1 bedroom flat
# 2          Added today  4 bedroom end of terrace house
# 3        Reduced today                  1 bedroom flat
# 4          Added today             1 bedroom apartment

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 pd.json_normalize(filtered_df, max_level=0)
#
# File c:\Users\danie\miniconda3\envs\venv-rental\Lib\site-packages\pandas\io\json\_normalize.py:460, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     457     return DataFrame(_simple_json_normalize(data, sep=sep))
#     459 if record_path is None:
# --> 460     if any([isinstance(x, dict) for x in y.values()] for y in data):
#     461         # naive normalization, this is idempotent for flat records
#     462         # and potentially will inflate the data considerably for
#     463         # deeply nested structures:
#     464         #  {VeryLong: { b: 1,c:2}} -> {VeryLong.b:1 ,VeryLong.c:@}
#     465         #
#     466         # TODO: handle record value which are lists, at least error
#     467         #       reasonably
#     468         data = nested_to_record(data, sep=sep, max_level=max_level)
#     469     return DataFrame(data)
#
# File c:\Users\danie\miniconda3\envs\venv-rental\Lib\site-packages\pandas\io\json\_normalize.py:460, in <genexpr>(.0)
#     457     return DataFrame(_simple_json_normalize(data, sep=sep))
#     459 if record_path is None:
# --> 460     if any([isinstance(x, dict) for x in y.values()] for y in data):
#     461         # naive normalization, this is idempotent for flat records
#     462         # and potentially will inflate the data considerably for
#     463         # deeply nested structures:
#     464         #  {VeryLong: { b: 1,c:2}} -> {VeryLong.b:1 ,VeryLong.c:@}
#     465         #
#     466         # TODO: handle record value which are lists, at least error
#     467         #       reasonably
#     468         data = nested_to_record(data, sep=sep, max_level=max_level)
#     469     return DataFrame(data)
#
# AttributeError: 'str' object has no attribute 'values'

# %% [markdown]
# ### Explode the columns that are lists

# %%
def flatten_df(filtered_df):
    df = filtered_df.copy()

    # Extract nearest station names and distances
    def extract_stations(stations, key):
        if not isinstance(stations, list): # if stations is not a list, return None for all three
            return [None] * 3
        # Extract the first three stations' names or distances, or None if not available
        return [s.get(key) if isinstance(s, dict) else None for s in stations[:3]] + [None] * (3 - len(stations))

    # Apply the extraction function to the nearest_stations column
    df[['station_1_name', 'station_2_name', 'station_3_name']] = df['nearest_stations'].apply(lambda x: pd.Series(extract_stations(x, 'name')))
    df[['station_1_dist', 'station_2_dist', 'station_3_dist']] = df['nearest_stations'].apply(lambda x: pd.Series(extract_stations(x, 'distance')))

    # Extract sizings with unit == "sqm"
    def extract_sqm(sizings):
        if not isinstance(sizings, list): # if sizings is not a list, return None
            return pd.Series([None, None])
        for s in sizings: # loop through each element (each one is a dictionary) in the sizings list
            if isinstance(s, dict) and s.get('unit') == 'sqm': # if the dictionary has a 'unit' key with value 'sqm'
                return pd.Series([s.get('min'), s.get('max')]) # return the min and max values of the sizing measurement
        return pd.Series([None, None]) # else return None for both min and max
    
    # Apply the extraction function to the sizings column
    df[['size_min_sqm', 'size_max_sqm']] = df['sizings'].apply(extract_sqm)


     # Normalize the 'history' and 'address' nested dictionaries
    history_df = pd.json_normalize(df['history'])  # flatten the nested dict in history
    history_df.columns = [f'history_{str.lower(col)}' for col in history_df.columns]  # prefix with 'history_'

    address_df = pd.json_normalize(df['address'])  # flatten the nested dict in address
    address_df.columns = [f'{str.lower(col)}' for col in address_df.columns]  # prefix with 'address_'

    # Concatenate the new columns and drop the originals
    df = pd.concat([df.drop(columns=['nearest_stations', 'sizings', 'history', 'address']), history_df, address_df], axis=1)

    return df




flattened_df = flatten_df(filtered_df)
flattened_df.head()
# Out:
#           id  available  archived  bedrooms  bathrooms property_type  \
# 0  163907069       True     False         2          1          Flat
# 1  163907291       True     False         2          2     Apartment
#
#                                          description  \
# 0  A charming split level two bedroom apartment t...
# 1  Located on the 6th floor, is this gorgeous two...
#
#                                                title             subtitle  \
# 0  2 bedroom flat for rent in Bassano Street, Lon...       2 bedroom flat
# 1  2 bedroom apartment for rent in The Modern, Em...  2 bedroom apartment
#
#         price price_sqft   latitude  longitude  \
# 0  £2,400 pcm       None  51.456039  -0.075196
# 1  £4,400 pcm       None  51.482636  -0.129653
#
#                                             features        station_1_name  \
# 0  [-\tTwo double bedrooms, -             Spaciou...  East Dulwich Station
# 1  [Available Now, Virtual tour available, Fully ...     Nine Elms Station
#
#           station_2_name        station_3_name  station_1_dist  \
# 0  North Dulwich Station  Denmark Hill Station        0.444656
# 1       Vauxhall Station       Pimlico Station        0.196516
#
#    station_2_dist  station_3_dist  size_min_sqm  size_max_sqm  \
# 0        0.600147        1.048489           NaN           NaN
# 1        0.347126        0.485662          75.0          75.0
#
#   history_listingupdatereason                     displayaddress countrycode  \
# 0             Added yesterday       Bassano Street, London, SE22          GB
# 1             Added yesterday  The Modern, Embassy Gardens, SW11          GB
#
#    deliverypointid ukcountry outcode incode
# 0              NaN   England    SE22    8RY
# 1      107171035.0   England    SW11    7AY

# %% [markdown]
# ### Select only the very most essential columns

# %%
core_df = flattened_df[['id',
                       'bedrooms',
                       'bathrooms',
                       'price',
                       'latitude',
                       'longitude',
                       'station_1_name',
                       'station_1_dist',
                       'size_min_sqm',
                       'size_max_sqm',
                       'displayaddress']]

# %%
def clean_price(df):
    # Make a copy to avoid modifying the original DataFrame
    df = df.copy()
    # Remove pound sign and commas, extract numeric part, and convert to float
    df['price'] = (
        df['price']
        .str.replace('£', '', regex=False)
        .str.replace(',', '', regex=False)
        .str.extract(r'(\d+)')
        .astype(float)
    )
    return df

# %%
clean_price(core_df)
# Out:
#           id  bedrooms  bathrooms   price   latitude  longitude  \
# 0  163907069         2          1  2400.0  51.456039  -0.075196
# 1  163907291         2          2  4400.0  51.482636  -0.129653
#
#          station_1_name  station_1_dist  size_min_sqm  size_max_sqm  \
# 0  East Dulwich Station        0.444656           NaN           NaN
# 1     Nine Elms Station        0.196516          75.0          75.0
#
#                       displayaddress
# 0       Bassano Street, London, SE22
# 1  The Modern, Embassy Gardens, SW11
