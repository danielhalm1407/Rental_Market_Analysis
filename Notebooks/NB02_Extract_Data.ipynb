# %% [markdown]
# # Collecting Data From Rightmove Listings

# %% [markdown]
# Before extracting the target data, I use this notebook to practice the use of a hidden API in the QS University Rankings website, that way guaging the functionality.

# %% [markdown]
# ## Import Packages

# %%
# Web - Scraping and API Requests
import requests
from httpx import AsyncClient, Response
from parsel import Selector
import parsel
import jmespath
import asyncio

# Data Manipulation and Analysis
import pandas as pd
from pprint import pprint 
import json
from typing import List
from typing import TypedDict

# Database Connection
from sqlalchemy import create_engine

# File and System Operations
import os
import sys

# %%
pd.set_option('display.max_columns', None) # Display all columns in any given DataFrame

# %%
# This allows one to reload the custom package without having to install it again
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# this allows one to reload the custom package without having to install it again
# %autoreload 1

sys.path.insert(0,'../src/')

# https://stackoverflow.com/questions/70898150/jupyter-autoreload-workflow/73623267#73623267
# My custom package
# %aimport rental_utils

# %%
# Load SQL Magic for Jupyter Notebooks
# %load_ext sql
# %config SqlMagic.displaylimit = None
# %config SqlMagic.autocommit=True # for engines that do not support autommit
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# displaylimit: Value None will be treated as 0 (no limit)

# %% [markdown]
# ## Set Up An Initial Request

# %% [markdown]
# ### Establish Headers

# %%
# 1. establish HTTP client with browser-like headers to avoid being blocked
client = AsyncClient(
    headers={
        "User-Agent": "Mozilla/5.0",
        "Accept": "text/html",
    }
)

# %% [markdown]
# ### Define a function that parses rightmove property data to only get the relevant fields

# %%
class PropertyResult(TypedDict):
    """this is what our result dataset will look like"""
    id: str
    available: bool
    archived: bool
    phone: str
    bedrooms: int
    bathrooms: int
    type: str
    property_type: str
    tags: list
    description: str
    title: str
    subtitle: str
    price: str
    price_sqft: str
    address: dict
    latitude: float
    longitude: float
    features: list
    history: dict
    photos: list
    floorplans: list
    agency: dict
    industryAffiliations: list
    nearest_airports: list
    nearest_stations: list
    sizings: list
    brochures: list


def parse_property(data) -> PropertyResult:
    """parse rightmove cache data for proprety information"""
    # here we define field name to JMESPath mapping
    parse_map = {
        "id": "id",
        "available": "status.published",
        "archived": "status.archived",
        "phone": "contactInfo.telephoneNumbers.localNumber",
        "bedrooms": "bedrooms",
        "bathrooms": "bathrooms",
        "type": "transactionType",
        "property_type": "propertySubType",
        "tags": "tags",
        "description": "text.description",
        "title": "text.pageTitle",
        "subtitle": "text.propertyPhrase",
        "price": "prices.primaryPrice",
        "price_sqft": "prices.pricePerSqFt",
        "address": "address",
        "latitude": "location.latitude",
        "longitude": "location.longitude",
        "features": "keyFeatures",
        "history": "listingHistory",
        "photos": "images[*].{url: url, caption: caption}",
        "floorplans": "floorplans[*].{url: url, caption: caption}",
        "agency": """customer.{
            id: branchId, 
            branch: branchName, 
            company: companyName, 
            address: displayAddress, 
            commercial: commercial, 
            buildToRent: buildToRent,
            isNew: isNewHomeDeveloper
        }""",
        "industryAffiliations": "industryAffiliations[*].name",
        "nearest_airports": "nearestAirports[*].{name: name, distance: distance}",
        "nearest_stations": "nearestStations[*].{name: name, distance: distance}",
        "sizings": "sizings[*].{unit: unit, min: minimumSize, max: maximumSize}",
        "brochures": "brochures",
    }
    results = {}
    for key, path in parse_map.items():
        value = jmespath.search(path, data)
        results[key] = value
    return results

# %% [markdown]
# ### Define a Function that Will Find JSON objects in text, and generate decoded JSON data

# %%
def find_json_objects(text: str, decoder=json.JSONDecoder()):
    """Find JSON objects in text, and generate decoded JSON data"""
    pos = 0
    while True:
        match = text.find("{", pos)
        if match == -1:
            break
        try:
            result, index = decoder.raw_decode(text[match:])
            yield result
            pos = match + index
        except ValueError:
            pos = match + 1

# %% [markdown]
# ### Define a function that will find the PAGE_MODEL javascript variable and extract it

# %%
# This function will find the PAGE_MODEL javascript variable and extract it 
def extract_property(response: Response) -> dict:
    """extract property data from rightmove PAGE_MODEL javascript variable"""
    selector = Selector(response.text)
    data = selector.xpath("//script[contains(.,'PAGE_MODEL = ')]/text()").get()
    if not data:
        print(f"page {response.url} is not a property listing page")
        return
    json_data = list(find_json_objects(data))[0]
    return json_data["propertyData"]

# %% [markdown]
# ### Define the primary scraping function that takes urls and returns the data

# %%
async def scrape_properties(urls: List[str]) -> List[dict]:
    """
    Scrape Rightmove property listings from a list of URLs,
    parse relevant fields, and save all results to a single JSON file.
    """
    # Prepare asynchronous GET requests for all URLs using the shared client
    to_scrape = [client.get(url) for url in urls]

    # List to store parsed property data
    properties = []

    # Asynchronously process each response as it completes
    for response in asyncio.as_completed(to_scrape):
        # Await the HTTP response for the property page
        response = await response

        # Extract and parse the property data from the response
        prop = parse_property(extract_property(response))

        # Add the parsed property data to the list
        properties.append(prop)

    # Save all parsed properties as a single JSON array to disk
    with open("../data/rightmove_properties.json", "w", encoding="utf-8") as f:
        json.dump(properties, f, indent=2)

    # Return the list of parsed property dictionaries
    return properties

# %% [markdown]
# ### Define a running script

# %%
async def run():
    data = await scrape_properties([
        "https://www.rightmove.co.uk/properties/163907069#/",
        "https://www.rightmove.co.uk/properties/163907291#/",
    ])

    print(json.dumps(data, indent=2))

# %%
await run()
await client.aclose()
# Out:
# [
#   {
#     "id": "163907069",
#     "available": true,
#     "archived": false,
#     "phone": "020 3872 4834",
#     "bedrooms": 2,
#     "bathrooms": 1,
#     "type": "RENT",
#     "property_type": "Flat",
#     "tags": [],
#     "description": "A charming split level two bedroom apartment to rent with access to a private roof terrace in the centre of East Dulwich.<br /><br />\rLocated on this great road just off the vibrant Lordship Lane is this charming split level two bedroom apartment to rent. With beautiful views over London and a large decked private roof terrace. Features include a spacious reception room and separate fully fitted kitchen. Available end of July. <br /><br />Additional Information<br /><br />Holding Deposit: \u00a3553.84 (1 week)*<br />Tenancy Deposit: \u00a32769.23 (5 weeks)*<br />Council Tax Band: D<br /><br />*The deposit amounts are approximate and will vary depending on the final rent agreed.<br /><br />",
#     "title": "2 bedroom flat for rent in Bassano Street, London, SE22",
#     "subtitle": "2 bedroom flat",
#     "price": "\u00a32,400 pcm",
#     "price_sqft": null,
#     "address": {
#       "displayAddress": "Bassano Street, London, SE22",
#       "countryCode": "GB",
#       "deliveryPointId": null,
#       "ukCountry": "England",
#       "outcode": "SE22",
#       "incode": "8RY"
#     },
#     "latitude": 51.456039,
#     "longitude": -0.075196,
#     "features": [
#       "-\tTwo double bedrooms",
#       "-             Spacious reception",
#       "-\tLarge Private Roof Terrace",
#       "-\tStripped Wood Flooring",
#       "-\tPrime East Dulwich Location",
#       "-\tAvailable end of July"
#     ],
#     "history": {
#       "listingUpdateReason": "Added yesterday"
#     },
#     "photos": [
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_00_0000.jpeg",
#         "caption": "Picture No. 18"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_01_0000.jpeg",
#         "caption": "Picture No. 24"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_02_0000.jpeg",
#         "caption": "Picture No. 21"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_03_0000.jpeg",
#         "caption": "Picture No. 29"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_04_0000.jpeg",
#         "caption": "Picture No. 27"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_05_0000.jpeg",
#         "caption": "Picture No. 15"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_06_0000.jpeg",
#         "caption": "Picture No. 16"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_07_0000.jpeg",
#         "caption": "Picture No. 19"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_08_0000.jpeg",
#         "caption": "Picture No. 23"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_09_0000.jpeg",
#         "caption": "Picture No. 26"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_10_0000.jpeg",
#         "caption": "Picture No. 28"
#       },
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_IMG_11_0000.jpeg",
#         "caption": "Picture No. 22"
#       }
#     ],
#     "floorplans": [
#       {
#         "url": "https://media.rightmove.co.uk/58k/57994/163907069/57994_KDI220013_L_FLP_00_0000.gif",
#         "caption": "Floorplan (002)"
#       }
#     ],
#     "agency": {
#       "id": 57994,
#       "branch": "East Dulwich",
#       "company": "Kinleigh Folkard & Hayward",
#       "address": "107 - 109 Lordship Lane\r\nLondon,\r\nSE22 8HU ",
#       "commercial": false,
#       "buildToRent": false,
#       "isNew": false
#     },
#     "industryAffiliations": [
#       "Property Redress Scheme"
#     ],
#     "nearest_airports": [],
#     "nearest_stations": [
#       {
#         "name": "East Dulwich Station",
#         "distance": 0.4446564582122654
#       },
#       {
#         "name": "North Dulwich Station",
#         "distance": 0.6001469769776864
#       },
#       {
#         "name": "Denmark Hill Station",
#         "distance": 1.0484889571347127
#       }
#     ],
#     "sizings": [],
#     "brochures": []
#   },
#   {
#     "id": "163907291",
#     "available": true,
#     "archived": false,
#     "phone": "020 3835 3553",
#     "bedrooms": 2,
#     "bathrooms": 2,
#     "type": "RENT",
#     "property_type": "Apartment",
#     "tags": [],
#     "description": "Located on the 6th floor, is this gorgeous two bedroom, two bathroom corner unit offering jaw dropping views of Thames City & The Shard. Spread over 807 Sq.Ft this lateral apartment sits on the best plot position of the building, with an over sized living room that is bathed in light and further heightened with access to a private balcony makes for the perfect in-out flow. <br /><br />Apartment Features:<br />- Corner apartment <br />- Direct view of The Shard<br />- Designed by London-based duo Benningen & Lloyd<br />- Rare marble, crafted tiles with mood lit bathrooms<br />- Wine cooler <br />- Underfloor heating and comfort cooling<br /><br />Resident Exclusive Amenities:<br />- Access to the infamous Sky Pool <br />- Orangery rooftop <br />- 24/7 concierge <br />- State of the art gym <br />- Business lounge<br />- Cinema room<br /><br />Embassy Gardens is a 21st-century development on the South Bank of London, looking across the River Thames to Chelsea and Kensington. With its own green space, art trail, shops, restaurants and caf\u00e9s, Embassy Gardens offers residents and their guests the complete London experience in the centre of the city.<br /><br />3 minute walk to the new Nine Elms tube station<br />10 minute walk to Vauxhall overground/tube station<br />7 minutes to Oxford Circus from Vauxhall station<br />12 minutes to Eurostar and Kings Cross from Vauxhall station<br />24 minute walk to Battersea Park",
#     "title": "2 bedroom apartment for rent in The Modern, Embassy Gardens, SW11",
#     "subtitle": "2 bedroom apartment",
#     "price": "\u00a34,400 pcm",
#     "price_sqft": null,
#     "address": {
#       "displayAddress": "The Modern, Embassy Gardens, SW11",
#       "countryCode": "GB",
#       "deliveryPointId": 107171035,
#       "ukCountry": "England",
#       "outcode": "SW11",
#       "incode": "7AY"
#     },
#     "latitude": 51.482636,
#     "longitude": -0.129653,
#     "features": [
#       "Available Now",
#       "Virtual tour available",
#       "Fully furnished",
#       "Direct views of The Shard",
#       "Corner apartment",
#       "Underfloor heating",
#       "Access to Sky Pool",
#       "24/7 concierge",
#       "Residents gym",
#       "Cinema room"
#     ],
#     "history": {
#       "listingUpdateReason": "Added yesterday"
#     },
#     "photos": [
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_00_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_01_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_02_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_03_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_04_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_05_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_06_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_07_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_08_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_09_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_10_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_11_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_12_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_13_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_14_0000.jpeg",
#         "caption": null
#       },
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_15_0000.jpeg",
#         "caption": null
#       }
#     ],
#     "floorplans": [
#       {
#         "url": "https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_FLP_00_0000.jpeg",
#         "caption": "Floorplan 1"
#       }
#     ],
#     "agency": {
#       "id": 264404,
#       "branch": "London",
#       "company": "ROMANS & PARTNERS LIMITED",
#       "address": "40 Bank Street,\r\nCanary Wharf\r\nE14 5NR",
#       "commercial": false,
#       "buildToRent": false,
#       "isNew": false
#     },
#     "industryAffiliations": [],
#     "nearest_airports": [],
#     "nearest_stations": [
#       {
#         "name": "Nine Elms Station",
#         "distance": 0.19651556985347293
#       },
#       {
#         "name": "Vauxhall Station",
#         "distance": 0.3471264804749964
#       },
#       {
#         "name": "Pimlico Station",
#         "distance": 0.48566173864343737
#       }
#     ],
#     "sizings": [
#       {
#         "unit": "ha",
#         "min": 0.01,
#         "max": 0.01
#       },
#       {
#         "unit": "sqm",
#         "min": 75,
#         "max": 75
#       },
#       {
#         "unit": "sqft",
#         "min": 807,
#         "max": 807
#       },
#       {
#         "unit": "ac",
#         "min": 0.02,
#         "max": 0.02
#       }
#     ],
#     "brochures": []
#   }
# ]

# %%
with open("../data/rightmove_properties.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
display(data[0])
# Out:
# {'id': '163907291',
#  'available': True,
#  'archived': False,
#  'phone': '020 3835 3553',
#  'bedrooms': 2,
#  'bathrooms': 2,
#  'type': 'RENT',
#  'property_type': 'Apartment',
#  'tags': [],
#  'description': 'Located on the 6th floor, is this gorgeous two bedroom, two bathroom corner unit offering jaw dropping views of Thames City & The Shard. Spread over 807 Sq.Ft this lateral apartment sits on the best plot position of the building, with an over sized living room that is bathed in light and further heightened with access to a private balcony makes for the perfect in-out flow. <br /><br />Apartment Features:<br />- Corner apartment <br />- Direct view of The Shard<br />- Designed by London-based duo Benningen & Lloyd<br />- Rare marble, crafted tiles with mood lit bathrooms<br />- Wine cooler <br />- Underfloor heating and comfort cooling<br /><br />Resident Exclusive Amenities:<br />- Access to the infamous Sky Pool <br />- Orangery rooftop <br />- 24/7 concierge <br />- State of the art gym <br />- Business lounge<br />- Cinema room<br /><br />Embassy Gardens is a 21st-century development on the South Bank of London, looking across the River Thames to Chelsea and Kensington. With its own green space, art trail, shops, restaurants and cafés, Embassy Gardens offers residents and their guests the complete London experience in the centre of the city.<br /><br />3 minute walk to the new Nine Elms tube station<br />10 minute walk to Vauxhall overground/tube station<br />7 minutes to Oxford Circus from Vauxhall station<br />12 minutes to Eurostar and Kings Cross from Vauxhall station<br />24 minute walk to Battersea Park',
#  'title': '2 bedroom apartment for rent in The Modern, Embassy Gardens, SW11',
#  'subtitle': '2 bedroom apartment',
#  'price': '£4,400 pcm',
#  'price_sqft': None,
#  'address': {'displayAddress': 'The Modern, Embassy Gardens, SW11',
#   'countryCode': 'GB',
#   'deliveryPointId': 107171035,
#   'ukCountry': 'England',
#   'outcode': 'SW11',
#   'incode': '7AY'},
#  'latitude': 51.482636,
#  'longitude': -0.129653,
#  'features': ['Available Now',
#   'Virtual tour available',
#   'Fully furnished',
#   'Direct views of The Shard',
#   'Corner apartment',
#   'Underfloor heating',
#   'Access to Sky Pool',
#   '24/7 concierge',
#   'Residents gym',
#   'Cinema room'],
#  'history': {'listingUpdateReason': 'Added yesterday'},
#  'photos': [{'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_00_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_01_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_02_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_03_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_04_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_05_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_06_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_07_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_08_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_09_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_10_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_11_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_12_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_13_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_14_0000.jpeg',
#    'caption': None},
#   {'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_IMG_15_0000.jpeg',
#    'caption': None}],
#  'floorplans': [{'url': 'https://media.rightmove.co.uk/265k/264404/163907291/264404_RX596163_FLP_00_0000.jpeg',
#    'caption': 'Floorplan 1'}],
#  'agency': {'id': 264404,
#   'branch': 'London',
#   'company': 'ROMANS & PARTNERS LIMITED',
#   'address': '40 Bank Street,\r\nCanary Wharf\r\nE14 5NR',
#   'commercial': False,
#   'buildToRent': False,
#   'isNew': False},
#  'industryAffiliations': [],
#  'nearest_airports': [],
#  'nearest_stations': [{'name': 'Nine Elms Station',
#    'distance': 0.19651556985347293},
#   {'name': 'Vauxhall Station', 'distance': 0.3471264804749964},
#   {'name': 'Pimlico Station', 'distance': 0.48566173864343737}],
#  'sizings': [{'unit': 'ha', 'min': 0.01, 'max': 0.01},
#   {'unit': 'sqm', 'min': 75, 'max': 75},
#   {'unit': 'sqft', 'min': 807, 'max': 807},
#   {'unit': 'ac', 'min': 0.02, 'max': 0.02}],
#  'brochures': []}

# %% [markdown]
# ### Normalise th JSON so that it turns into a dataframe

# %%
data_norm = pd.json_normalize(data, max_level = 0)
data_norm.head()
# Out:
#           id  available  archived          phone  bedrooms  bathrooms  type  \
# 0  163907291       True     False  020 3835 3553         2          2  RENT
# 1  163907069       True     False  020 3872 4834         2          1  RENT
#
#   property_type tags                                        description  \
# 0     Apartment   []  Located on the 6th floor, is this gorgeous two...
# 1          Flat   []  A charming split level two bedroom apartment t...
#
#                                                title             subtitle  \
# 0  2 bedroom apartment for rent in The Modern, Em...  2 bedroom apartment
# 1  2 bedroom flat for rent in Bassano Street, Lon...       2 bedroom flat
#
#         price price_sqft                                            address  \
# 0  £4,400 pcm       None  {'displayAddress': 'The Modern, Embassy Garden...
# 1  £2,400 pcm       None  {'displayAddress': 'Bassano Street, London, SE...
#
#     latitude  longitude                                           features  \
# 0  51.482636  -0.129653  [Available Now, Virtual tour available, Fully ...
# 1  51.456039  -0.075196  [-\tTwo double bedrooms, -             Spaciou...
#
#                                       history  \
# 0  {'listingUpdateReason': 'Added yesterday'}
# 1  {'listingUpdateReason': 'Added yesterday'}
#
#                                               photos  \
# 0  [{'url': 'https://media.rightmove.co.uk/265k/2...
# 1  [{'url': 'https://media.rightmove.co.uk/58k/57...
#
#                                           floorplans  \
# 0  [{'url': 'https://media.rightmove.co.uk/265k/2...
# 1  [{'url': 'https://media.rightmove.co.uk/58k/57...
#
#                                               agency  \
# 0  {'id': 264404, 'branch': 'London', 'company': ...
# 1  {'id': 57994, 'branch': 'East Dulwich', 'compa...
#
#         industryAffiliations nearest_airports  \
# 0                         []               []
# 1  [Property Redress Scheme]               []
#
#                                     nearest_stations  \
# 0  [{'name': 'Nine Elms Station', 'distance': 0.1...
# 1  [{'name': 'East Dulwich Station', 'distance': ...
#
#                                              sizings brochures
# 0  [{'unit': 'ha', 'min': 0.01, 'max': 0.01}, {'u...        []
# 1                                                 []        []

# %% [markdown]
# ### Filter out only the desired columns

# %%
def filter_df(df=data):
    results_df = pd.json_normalize(df, max_level=0)
    results_df.columns = results_df.columns.str.lower().str.replace('.', '_').str.replace(' ', '_')
    base_cols = [
        'id',
        'available',
        'archived',
        'bedrooms',
        'bathrooms',
        'property_type',
        'description',
        'title',
        'subtitle',
        'price',
        'price_sqft',
        'latitude',
        'longitude',
        'nearest_stations',
        'sizings',
        'history',
        'address',
        'features'
    ]
    columns_of_interest = base_cols
    filtered_df = results_df[columns_of_interest]
    return filtered_df


filtered_df = filter_df(data)
filtered_df.head()
# Out:
#           id  available  archived  bedrooms  bathrooms property_type  \
# 0  163907291       True     False         2          2     Apartment
# 1  163907069       True     False         2          1          Flat
#
#                                          description  \
# 0  Located on the 6th floor, is this gorgeous two...
# 1  A charming split level two bedroom apartment t...
#
#                                                title             subtitle  \
# 0  2 bedroom apartment for rent in The Modern, Em...  2 bedroom apartment
# 1  2 bedroom flat for rent in Bassano Street, Lon...       2 bedroom flat
#
#         price price_sqft   latitude  longitude  \
# 0  £4,400 pcm       None  51.482636  -0.129653
# 1  £2,400 pcm       None  51.456039  -0.075196
#
#                                     nearest_stations  \
# 0  [{'name': 'Nine Elms Station', 'distance': 0.1...
# 1  [{'name': 'East Dulwich Station', 'distance': ...
#
#                                              sizings  \
# 0  [{'unit': 'ha', 'min': 0.01, 'max': 0.01}, {'u...
# 1                                                 []
#
#                                       history  \
# 0  {'listingUpdateReason': 'Added yesterday'}
# 1  {'listingUpdateReason': 'Added yesterday'}
#
#                                              address  \
# 0  {'displayAddress': 'The Modern, Embassy Garden...
# 1  {'displayAddress': 'Bassano Street, London, SE...
#
#                                             features
# 0  [Available Now, Virtual tour available, Fully ...
# 1  [-\tTwo double bedrooms, -             Spaciou...

# %% [markdown]
# ### Explode the columns that are lists

# %%
def flatten_df(filtered_df):
    df = filtered_df.copy()

    # Extract nearest station names and distances
    def extract_stations(stations, key):
        if not isinstance(stations, list): # if stations is not a list, return None for all three
            return [None] * 3
        # Extract the first three stations' names or distances, or None if not available
        return [s.get(key) if isinstance(s, dict) else None for s in stations[:3]] + [None] * (3 - len(stations))

    # Apply the extraction function to the nearest_stations column
    df[['station_1_name', 'station_2_name', 'station_3_name']] = df['nearest_stations'].apply(lambda x: pd.Series(extract_stations(x, 'name')))
    df[['station_1_dist', 'station_2_dist', 'station_3_dist']] = df['nearest_stations'].apply(lambda x: pd.Series(extract_stations(x, 'distance')))

    # Extract sizings with unit == "sqm"
    def extract_sqm(sizings):
        if not isinstance(sizings, list): # if sizings is not a list, return None
            return pd.Series([None, None])
        for s in sizings: # loop through each element (each one is a dictionary) in the sizings list
            if isinstance(s, dict) and s.get('unit') == 'sqm': # if the dictionary has a 'unit' key with value 'sqm'
                return pd.Series([s.get('min'), s.get('max')]) # return the min and max values of the sizing measurement
        return pd.Series([None, None]) # else return None for both min and max
    
    # Apply the extraction function to the sizings column
    df[['size_min_sqm', 'size_max_sqm']] = df['sizings'].apply(extract_sqm)


     # Normalize the 'history' and 'address' nested dictionaries
    history_df = pd.json_normalize(df['history'])  # flatten the nested dict in history
    history_df.columns = [f'history_{str.lower(col)}' for col in history_df.columns]  # prefix with 'history_'

    address_df = pd.json_normalize(df['address'])  # flatten the nested dict in address
    address_df.columns = [f'{str.lower(col)}' for col in address_df.columns]  # prefix with 'address_'

    # Concatenate the new columns and drop the originals
    df = pd.concat([df.drop(columns=['nearest_stations', 'sizings', 'history', 'address']), history_df, address_df], axis=1)

    return df




flattened_df = flatten_df(filtered_df)
flattened_df.head()
# Out:
#           id  available  archived  bedrooms  bathrooms property_type  \
# 0  163907291       True     False         2          2     Apartment
# 1  163907069       True     False         2          1          Flat
#
#                                          description  \
# 0  Located on the 6th floor, is this gorgeous two...
# 1  A charming split level two bedroom apartment t...
#
#                                                title             subtitle  \
# 0  2 bedroom apartment for rent in The Modern, Em...  2 bedroom apartment
# 1  2 bedroom flat for rent in Bassano Street, Lon...       2 bedroom flat
#
#         price price_sqft   latitude  longitude  \
# 0  £4,400 pcm       None  51.482636  -0.129653
# 1  £2,400 pcm       None  51.456039  -0.075196
#
#                                             features        station_1_name  \
# 0  [Available Now, Virtual tour available, Fully ...     Nine Elms Station
# 1  [-\tTwo double bedrooms, -             Spaciou...  East Dulwich Station
#
#           station_2_name        station_3_name  station_1_dist  \
# 0       Vauxhall Station       Pimlico Station        0.196516
# 1  North Dulwich Station  Denmark Hill Station        0.444656
#
#    station_2_dist  station_3_dist  size_min_sqm  size_max_sqm  \
# 0        0.347126        0.485662          75.0          75.0
# 1        0.600147        1.048489           NaN           NaN
#
#   history_listingupdatereason                     displayaddress countrycode  \
# 0             Added yesterday  The Modern, Embassy Gardens, SW11          GB
# 1             Added yesterday       Bassano Street, London, SE22          GB
#
#    deliverypointid ukcountry outcode incode
# 0      107171035.0   England    SW11    7AY
# 1              NaN   England    SE22    8RY

# %% [markdown]
# ### Select only the very most essential columns

# %%
core_df = flattened_df[['id',
                       'bedrooms',
                       'bathrooms',
                       'price',
                       'latitude',
                       'longitude',
                       'station_1_name',
                       'station_1_dist',
                       'size_min_sqm',
                       'size_max_sqm',
                       'displayaddress']]

# %%
def clean_price(df):
    # Make a copy to avoid modifying the original DataFrame
    df = df.copy()
    # Remove pound sign and commas, extract numeric part, and convert to float
    df['price'] = (
        df['price']
        .str.replace('£', '', regex=False)
        .str.replace(',', '', regex=False)
        .str.extract(r'(\d+)')
        .astype(float)
    )
    return df

# %%
clean_price(core_df)
# Out:
#           id  bedrooms  bathrooms   price   latitude  longitude  \
# 0  163907291         2          2  4400.0  51.482636  -0.129653
# 1  163907069         2          1  2400.0  51.456039  -0.075196
#
#          station_1_name  station_1_dist  size_min_sqm  size_max_sqm  \
# 0     Nine Elms Station        0.196516          75.0          75.0
# 1  East Dulwich Station        0.444656           NaN           NaN
#
#                       displayaddress
# 0  The Modern, Embassy Gardens, SW11
# 1       Bassano Street, London, SE22
