# %% [markdown]
# # Clean the Property Data Gathered

# %% [markdown]
# ## Import Packages

# %%
# Web - Scraping and API Requests
import requests
from httpx import AsyncClient, Response
from parsel import Selector
import parsel
import jmespath
import asyncio

# Data Manipulation and Analysis
import pandas as pd
from pprint import pprint 
import json
from typing import List
from typing import TypedDict

# Database Connection
from sqlalchemy import create_engine

# File and System Operations
import os
import sys

# %%
pd.set_option('display.max_columns', None) # Display all columns in any given DataFrame

# %%
# This allows one to reload the custom package without having to install it again
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# this allows one to reload the custom package without having to install it again
# %autoreload 1

sys.path.insert(0,'../src/')

# Import the custom package
# %aimport rental_utils
# %aimport rental_utils.functions

# %%
# Load SQL Magic for Jupyter Notebooks
# %load_ext sql
# %config SqlMagic.displaylimit = None
# %config SqlMagic.autocommit=True # for engines that do not support autommit
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# displaylimit: Value None will be treated as 0 (no limit)

# %% [markdown]
# ## Clean the data for selected urls

# %%
with open("../data/rightmove_properties.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
display(data[0])
# Out:
# {'id': 161816171,
#  'bedrooms': 2,
#  'bathrooms': 1,
#  'numberOfImages': 9,
#  'numberOfFloorplans': 1,
#  'numberOfVirtualTours': 0,
#  'summary': 'A spacious two-bedroom flat on the top floor provides comfortable living accommodation.',
#  'displayAddress': 'Rosendale Road London SE21',
#  'countryCode': 'GB',
#  'location': {'latitude': 51.4331, 'longitude': -0.09298},
#  'propertyImages': {'images': [{'url': '69k/68804/161816171/68804_P300092_IMG_00_0000.jpeg',
#     'caption': 'ROSENDALE ROAD, 1...',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_00_0000_max_476x317.jpeg'},
#    {'url': '69k/68804/161816171/68804_P300092_IMG_01_0000.jpeg',
#     'caption': 'ROSENDALE ROAD, 1...',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_01_0000_max_476x317.jpeg'},
#    {'url': '69k/68804/161816171/68804_P300092_IMG_02_0000.jpeg',
#     'caption': 'ROSENDALE ROAD, 1...',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_02_0000_max_476x317.jpeg'},
#    {'url': '69k/68804/161816171/68804_P300092_IMG_03_0000.jpeg',
#     'caption': 'ROSENDALE ROAD, 1...',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_03_0000_max_476x317.jpeg'},
#    {'url': '69k/68804/161816171/68804_P300092_IMG_04_0000.jpeg',
#     'caption': 'ROSENDALE ROAD, 1...',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_04_0000_max_476x317.jpeg'},
#    {'url': '69k/68804/161816171/68804_P300092_IMG_05_0000.jpeg',
#     'caption': 'ROSENDALE ROAD, 1...',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_05_0000_max_476x317.jpeg'},
#    {'url': '69k/68804/161816171/68804_P300092_IMG_06_0000.jpeg',
#     'caption': 'ROSENDALE ROAD, 1...',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_06_0000_max_476x317.jpeg'},
#    {'url': '69k/68804/161816171/68804_P300092_IMG_07_0000.jpeg',
#     'caption': 'ROSENDALE ROAD, 1...',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_07_0000_max_476x317.jpeg'},
#    {'url': '69k/68804/161816171/68804_P300092_IMG_08_0000.jpeg',
#     'caption': 'ROSENDALE ROAD, 1...',
#     'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_08_0000_max_476x317.jpeg'}],
#   'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_00_0000_max_476x317.jpeg',
#   'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/69k/68804/161816171/68804_P300092_IMG_00_0000_max_296x197.jpeg'},
#  'propertySubType': 'Flat',
#  'listingUpdate': {'listingUpdateReason': 'new',
#   'listingUpdateDate': '2025-05-12T12:51:06Z'},
#  'price': {'amount': 2200,
#   'frequency': 'monthly',
#   'currencyCode': 'GBP',
#   'displayPrices': [{'displayPrice': '£2,200 pcm',
#     'displayPriceQualifier': ''},
#    {'displayPrice': '£508 pw', 'displayPriceQualifier': ''}]},
#  'premiumListing': False,
#  'featuredProperty': True,
#  'customer': {'branchId': 68804,
#   'brandPlusLogoURI': '/brand/brand_rmchoice_logo_25218_0003.jpeg',
#   'contactTelephone': '020 3869 0297',
#   'branchDisplayName': 'Hamptons, Dulwich',
#   'branchName': 'Dulwich',
#   'brandTradingName': 'Hamptons',
#   'branchLandingPageUrl': '/estate-agents/agent/Hamptons/Dulwich-68804.html',
#   'development': False,
#   'showReducedProperties': True,
#   'commercial': False,
#   'showOnMap': True,
#   'enhancedListing': False,
#   'developmentContent': None,
#   'buildToRent': False,
#   'buildToRentBenefits': [],
#   'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/brand/brand_rmchoice_logo_25218_0003.jpeg'},
#  'distance': None,
#  'transactionType': 'rent',
#  'productLabel': {'productLabelText': None, 'spotlightLabel': False},
#  'commercial': False,
#  'development': False,
#  'residential': True,
#  'students': False,
#  'auction': False,
#  'feesApply': True,
#  'feesApplyText': 'Hamptons Fees and Charges in England\n\nPermitted charges in accordance with the Tenant Fee Act 2019 for ASSURED SHORTHOLD TENANCY:\nHolding Deposit\t - Maximum one week s rent (may go on to form part of advance rent)\nFirst month s rent - In advance.\nTenancy Deposit - 5 weeks of agreed rent up to £50k rent per annum or 6 weeks of rent over £50k.\nEarly termination requested by the tenant - A charge not exceeding the financial loss experienced by the landlord.\nLate Rent - Interest charged at 3% above Bank of England base rate, when rent is more than 14 days late.\nLost key or security device - Equivalent to cost incurred.\nChanging the tenancy documents (after the commencement of the tenancy) - £50 inc. VAT.\n\nNON HOUSING ACT TENANCY fees (not affected by the Tenant Fee Act 2019)\nA Non Housing Act Tenancy is formed when one of the following criteria is in place: \nThe annual rent exceeds £100,000. \nThe property is occupied by an entity (Company let) rather that an individual. \nThe property is not used as a main or primary home. \nThere is a Resident Landlord.\nTenancy Agreement and Setup Administration - £390 inc VAT.\nCheck-in Fee checking into the property and reviewing inventory - Minimum of £130.80 inc VAT.\nEnhanced Reference Fee (per person or company) - £60 inc VAT.\nTenancy Continuation - £150 inc VAT.\nChange of Sharer - £120 inc VAT.\nEarly Termination - £150 inc VAT.\nLate payment of rent - Interest will be charged at 3% above the Bank of England base rate.\nGuarantor Referencing Fee - £60 inc VAT per guarantor.\nDeed of Guarantee - £50 inc VAT.\n\nStamp Duty Land Tax Payable on tenancies where the rent exceeds £125,000\nDuring the tenancy you may expect to pay:\nUtilities (gas, electricity, water)\nCouncil Tax\nBroadband, telephone, television licence\nSubscription to cable/satellite supplier\nInsurance (for your personal and own contents)\nGarden maintenance\nParking permits\n\nPlease note: The Initial Monies will be confirmed and must be paid by debit card or bank transfer. We are unable to accept cash. \nHamptons is a member of Propertymark and your monies are covered by the Propertymark Client Money Protection Scheme and a member of a redress scheme provided by The Property Ombudsman.\n',
#  'displaySize': '',
#  'showOnMap': True,
#  'propertyUrl': '/properties/161816171#/?channel=RES_LET',
#  'contactUrl': '/property-to-rent/contactBranch.html?propertyId=161816171',
#  'staticMapUrl': None,
#  'channel': 'RENT',
#  'firstVisibleDate': '2025-05-12T12:45:41Z',
#  'keywords': [],
#  'keywordMatchType': 'no_keyword',
#  'saved': False,
#  'hidden': False,
#  'onlineViewingsAvailable': False,
#  'lozengeModel': {'matchingLozenges': []},
#  'hasBrandPlus': True,
#  'displayStatus': '',
#  'enquiredTimestamp': None,
#  'enquiryAddedTimestamp': None,
#  'enquiryCalledTimestamp': None,
#  'heading': 'Featured Property',
#  'isRecent': False,
#  'enhancedListing': False,
#  'addedOrReduced': 'Added on 12/05/2025',
#  'formattedBranchName': ' by Hamptons, Dulwich',
#  'formattedDistance': '',
#  'propertyTypeFullDescription': '2 bedroom flat'}

# %% [markdown]
# ### Normalise th JSON so that it turns into a dataframe

# %%
data_norm = pd.json_normalize(data, max_level = 1)
data_norm.head(1)
# Out:
#           id  bedrooms  bathrooms  numberOfImages  numberOfFloorplans  \
# 0  161816171         2        1.0               9                   1
#
#    numberOfVirtualTours                                            summary  \
# 0                     0  A spacious two-bedroom flat on the top floor p...
#
#                displayAddress countryCode propertySubType  premiumListing  \
# 0  Rosendale Road London SE21          GB            Flat           False
#
#    featuredProperty distance transactionType  commercial  development  \
# 0              True     None            rent       False        False
#
#    residential  students  auction  feesApply  \
# 0         True     False    False       True
#
#                                        feesApplyText displaySize  showOnMap  \
# 0  Hamptons Fees and Charges in England\n\nPermit...                   True
#
#                                propertyUrl  \
# 0  /properties/161816171#/?channel=RES_LET
#
#                                           contactUrl staticMapUrl channel  \
# 0  /property-to-rent/contactBranch.html?propertyI...         None    RENT
#
#        firstVisibleDate keywords keywordMatchType  saved  hidden  \
# 0  2025-05-12T12:45:41Z       []       no_keyword  False   False
#
#    onlineViewingsAvailable  hasBrandPlus displayStatus enquiredTimestamp  \
# 0                    False          True                            None
#
#   enquiryAddedTimestamp enquiryCalledTimestamp            heading  isRecent  \
# 0                  None                   None  Featured Property     False
#
#    enhancedListing       addedOrReduced    formattedBranchName  \
# 0            False  Added on 12/05/2025   by Hamptons, Dulwich
#
#   formattedDistance propertyTypeFullDescription  location.latitude  \
# 0                                2 bedroom flat            51.4331
#
#    location.longitude                              propertyImages.images  \
# 0            -0.09298  [{'url': '69k/68804/161816171/68804_P300092_IM...
#
#                          propertyImages.mainImageSrc  \
# 0  https://media.rightmove.co.uk:443/dir/crop/10:...
#
#                       propertyImages.mainMapImageSrc  \
# 0  https://media.rightmove.co.uk:443/dir/crop/10:...
#
#   listingUpdate.listingUpdateReason listingUpdate.listingUpdateDate  \
# 0                               new            2025-05-12T12:51:06Z
#
#    price.amount price.frequency price.currencyCode  \
# 0          2200         monthly                GBP
#
#                                  price.displayPrices  customer.branchId  \
# 0  [{'displayPrice': '£2,200 pcm', 'displayPriceQ...              68804
#
#                     customer.brandPlusLogoURI customer.contactTelephone  \
# 0  /brand/brand_rmchoice_logo_25218_0003.jpeg             020 3869 0297
#
#   customer.branchDisplayName customer.branchName customer.brandTradingName  \
# 0          Hamptons, Dulwich             Dulwich                  Hamptons
#
#                       customer.branchLandingPageUrl  customer.development  \
# 0  /estate-agents/agent/Hamptons/Dulwich-68804.html                 False
#
#    customer.showReducedProperties  customer.commercial  customer.showOnMap  \
# 0                            True                False                True
#
#    customer.enhancedListing customer.developmentContent  customer.buildToRent  \
# 0                     False                        None                 False
#
#   customer.buildToRentBenefits  \
# 0                           []
#
#                            customer.brandPlusLogoUrl  \
# 0  https://media.rightmove.co.uk:443/brand/brand_...
#
#   productLabel.productLabelText  productLabel.spotlightLabel  \
# 0                          None                        False
#
#   lozengeModel.matchingLozenges
# 0                            []

# %% [markdown]
# ### Filter out only the desired columns

# %%
def filter_df(df: pd.DataFrame) -> pd.DataFrame:
    """
    Filters the input DataFrame to retain only the columns relevant for property analysis.

    Args:
        df (pd.DataFrame): The DataFrame to filter.

    Returns:
        pd.DataFrame: A DataFrame containing only the selected columns of interest.
    """
    # Define the list of columns to keep in the filtered DataFrame
    base_cols = [
        'id',
        'bedrooms',
        'bathrooms',
        'numberOfImages',
        'displayAddress',
        'location.latitude',
        'location.longitude',
        'propertySubType',
        'listingUpdate.listingUpdateReason',
        'listingUpdate.listingUpdateDate',
        'price.amount',
        'price.frequency',
        'premiumListing',
        'featuredProperty',
        'transactionType',
        'students',
        'displaySize',
        'propertyUrl',
        'firstVisibleDate',
        'addedOrReduced',
        'propertyTypeFullDescription'
    ]
    # Assign the columns of interest (can be extended or modified if needed)
    columns_of_interest = base_cols
    # Filter the DataFrame to include only the columns of interest
    filtered_df = df[columns_of_interest]
    # Return the filtered DataFrame
    return filtered_df


filtered_df = filter_df(data_norm)
filtered_df.head()
# Out:
#           id  bedrooms  bathrooms  numberOfImages  \
# 0  161816171         2        1.0               9
# 1  163971062         2        1.0              11
# 2  163971071         1        1.0               8
# 3  163971074         3        2.0              17
# 4  163971038         2        1.0               5
#
#                  displayAddress  location.latitude  location.longitude  \
# 0    Rosendale Road London SE21          51.433100           -0.092980
# 1     Marquess Road, London, N1          51.545995           -0.088096
# 2  Sevington Street, London, W9          51.524532           -0.192148
# 3  Highgate Road, Highgate, NW5          51.556260           -0.146437
# 4            Maybank House, E17          51.558100           -0.006540
#
#   propertySubType listingUpdate.listingUpdateReason  \
# 0            Flat                               new
# 1            Flat                               new
# 2       Apartment                               new
# 3      Maisonette                               new
# 4            Flat                               new
#
#   listingUpdate.listingUpdateDate  price.amount price.frequency  \
# 0            2025-05-12T12:51:06Z          2200         monthly
# 1            2025-06-30T15:31:13Z          3000         monthly
# 2            2025-06-30T15:31:13Z          1800         monthly
# 3            2025-06-30T15:31:13Z           980          weekly
# 4            2025-06-30T15:31:12Z          1750         monthly
#
#    premiumListing  featuredProperty transactionType  students displaySize  \
# 0           False              True            rent     False
# 1           False             False            rent     False   80 sq. m.
# 2           False             False            rent     False
# 3           False             False            rent     False
# 4           False             False            rent     False
#
#                                propertyUrl      firstVisibleDate  \
# 0  /properties/161816171#/?channel=RES_LET  2025-05-12T12:45:41Z
# 1  /properties/163971062#/?channel=RES_LET  2025-06-30T15:25:34Z
# 2  /properties/163971071#/?channel=RES_LET  2025-06-30T15:25:41Z
# 3  /properties/163971074#/?channel=RES_LET  2025-06-30T15:25:44Z
# 4  /properties/163971038#/?channel=RES_LET  2025-06-30T15:25:17Z
#
#         addedOrReduced propertyTypeFullDescription
# 0  Added on 12/05/2025              2 bedroom flat
# 1          Added today              2 bedroom flat
# 2          Added today         1 bedroom apartment
# 3          Added today        3 bedroom maisonette
# 4          Added today              2 bedroom flat

# %%
rental_utils.functions.filter_df(df=filtered_df)
# Out:
#            id  bedrooms  bathrooms  numberOfImages  \
# 0   161816171         2        1.0               9
# 1   163971062         2        1.0              11
# 2   163971071         1        1.0               8
# 3   163971074         3        2.0              17
# 4   163971038         2        1.0               5
# 5   163721564         0        1.0               8
# 6    86726619         1        1.0              18
# 7   163970990         0        1.0              10
# 8   163969877         1        NaN               2
# 9   163970711         2        1.0               8
# 10  163970927         1        1.0               6
# 11  163234211         1        1.0               6
# 12  162207071         2        2.0              12
# 13  163970933         2        2.0              14
# 14  163970921         3        1.0               5
# 15  163970897         1        1.0              11
# 16  158178944         3        3.0              17
# 17  163304876         0        1.0               7
# 18  163970885         1        1.0               6
# 19  163970867         2        2.0              19
# 20  163970870         1        1.0               6
# 21  161657795         2        1.0               9
# 22  163970783         3        1.0              10
# 23  161699705         1        1.0               7
# 24  163800473         0        1.0               4
#
#                                        displayAddress  location.latitude  \
# 0                          Rosendale Road London SE21          51.433100
# 1                           Marquess Road, London, N1          51.545995
# 2                        Sevington Street, London, W9          51.524532
# 3                        Highgate Road, Highgate, NW5          51.556260
# 4                                  Maybank House, E17          51.558100
# 5   Lighterman Point, 3 New Village Avenue, London...          51.513176
# 6            Rendel House, Goodluck Hope, London, E14          51.509024
# 7               Anchor House, St George Wharf, London          51.486236
# 8                          Cheyne Avenue, London, TW2          51.445480
# 9     Twickenham Gateway, Bradshaw Close, London, TW1          51.450470
# 10                 King Frederick Ninth Tower, London          51.496685
# 11                        Crescent Road, London, SE18          51.487512
# 12                 Pico House, 2 Prospect Way, London          51.480575
# 13           L-000083, 19 Circus Road West, Battersea          51.482004
# 14                          Stockwell Road, Stockwell          51.468847
# 15                       Hermitage Street, London, W2          51.519077
# 16              Tasker Lodge, \nThornwood Gardens, W8          51.504249
# 17                      Park West, \nEdgware Road, W2          51.515748
# 18  Adriatic Apartments, 20 Western Gateway, Londo...          51.508330
# 19                             Grove Vale London SE22          51.461480
# 20                            Gordon Road, London, W5          51.514856
# 21       Cedars Close, Belmont Hill, Blackheath, SE13          51.462970
# 22                       Browns Road, Walthamstow E17          51.587802
# 23                           Leinster Gardens, London          51.514237
# 24                            Edgware Road, Hyde Park          51.515667
#
#     location.longitude propertySubType listingUpdate.listingUpdateReason  \
# 0            -0.092980            Flat                               new
# 1            -0.088096            Flat                               new
# 2            -0.192148       Apartment                               new
# 3            -0.146437      Maisonette                               new
# 4            -0.006540            Flat                               new
# 5            -0.000335            Flat                     price_reduced
# 6             0.007284       Apartment                               new
# 7            -0.124846       Apartment                               new
# 8            -0.376380        Terraced                               new
# 9            -0.330020            Flat                               new
# 10           -0.032922        Detached                               new
# 11            0.070868            Flat                     price_reduced
# 12           -0.144021       Apartment                     price_reduced
# 13           -0.146368       Apartment                               new
# 14           -0.117663            Flat                               new
# 15           -0.176296            Flat                               new
# 16           -0.199328            Flat                     price_reduced
# 17           -0.164985            Flat                     price_reduced
# 18            0.018378            Flat                               new
# 19           -0.080050            Flat                               new
# 20           -0.307767            Flat                               new
# 21           -0.001360            Flat                     price_reduced
# 22           -0.019453        Terraced                               new
# 23           -0.184206            Flat                     price_reduced
# 24           -0.165019            Flat                     price_reduced
#
#    listingUpdate.listingUpdateDate  price.amount price.frequency  \
# 0             2025-05-12T12:51:06Z          2200         monthly
# 1             2025-06-30T15:31:13Z          3000         monthly
# 2             2025-06-30T15:31:13Z          1800         monthly
# 3             2025-06-30T15:31:13Z           980          weekly
# 4             2025-06-30T15:31:12Z          1750         monthly
# 5             2025-06-30T15:30:17Z          1600         monthly
# 6             2025-06-30T15:30:09Z           535          weekly
# 7             2025-06-30T15:30:07Z           496          weekly
# 8             2025-06-30T15:30:07Z           950         monthly
# 9             2025-06-30T15:30:04Z          2700         monthly
# 10            2025-06-30T15:30:02Z          2050         monthly
# 11            2025-06-30T15:29:45Z          1400         monthly
# 12            2025-06-30T15:29:24Z          1070          weekly
# 13            2025-06-30T15:29:12Z          4500         monthly
# 14            2025-06-30T15:29:12Z          2700         monthly
# 15            2025-06-30T15:29:10Z           650          weekly
# 16            2025-06-30T15:28:57Z         21666         monthly
# 17            2025-06-30T15:28:46Z          1750         monthly
# 18            2025-06-30T15:28:09Z          1700         monthly
# 19            2025-06-30T15:28:08Z          2500         monthly
# 20            2025-06-30T15:28:08Z          1700         monthly
# 21            2025-06-30T15:27:35Z          2600         monthly
# 22            2025-06-30T15:27:05Z          2400         monthly
# 23            2025-06-30T15:26:46Z           484          weekly
# 24            2025-06-30T15:26:46Z           403          weekly
#
#     premiumListing  featuredProperty transactionType  students displaySize  \
# 0            False              True            rent     False
# 1            False             False            rent     False   80 sq. m.
# 2            False             False            rent     False
# 3            False             False            rent     False
# 4            False             False            rent     False
# 5            False             False            rent     False
# 6            False             False            rent     False   51 sq. m.
# 7            False             False            rent     False   34 sq. m.
# 8            False             False            rent      True
# 9            False             False            rent     False
# 10           False             False            rent     False
# 11           False             False            rent     False
# 12            True             False            rent     False
# 13           False             False            rent     False
# 14           False             False            rent     False
# 15           False             False            rent     False   40 sq. m.
# 16            True             False            rent     False  242 sq. m.
# 17           False             False            rent     False   24 sq. m.
# 18           False             False            rent     False
# 19           False             False            rent     False
# 20           False             False            rent     False
# 21           False             False            rent     False
# 22           False             False            rent      True  105 sq. m.
# 23           False             False            rent     False
# 24           False             False            rent     False
#
#                                 propertyUrl      firstVisibleDate  \
# 0   /properties/161816171#/?channel=RES_LET  2025-05-12T12:45:41Z
# 1   /properties/163971062#/?channel=RES_LET  2025-06-30T15:25:34Z
# 2   /properties/163971071#/?channel=RES_LET  2025-06-30T15:25:41Z
# 3   /properties/163971074#/?channel=RES_LET  2025-06-30T15:25:44Z
# 4   /properties/163971038#/?channel=RES_LET  2025-06-30T15:25:17Z
# 5   /properties/163721564#/?channel=RES_LET  2025-06-24T11:55:03Z
# 6    /properties/86726619#/?channel=RES_LET  2024-01-09T19:05:03Z
# 7   /properties/163970990#/?channel=RES_LET  2025-06-30T15:24:43Z
# 8   /properties/163969877#/?channel=RES_LET  2025-06-30T15:24:43Z
# 9   /properties/163970711#/?channel=RES_LET  2025-06-30T15:24:20Z
# 10  /properties/163970927#/?channel=RES_LET  2025-06-30T15:23:43Z
# 11  /properties/163234211#/?channel=RES_LET  2025-06-12T17:08:11Z
# 12  /properties/162207071#/?channel=RES_LET  2025-05-20T16:51:40Z
# 13  /properties/163970933#/?channel=RES_LET  2025-06-30T15:23:53Z
# 14  /properties/163970921#/?channel=RES_LET  2025-06-30T15:23:38Z
# 15  /properties/163970897#/?channel=RES_LET  2025-06-30T15:23:09Z
# 16  /properties/158178944#/?channel=RES_LET  2025-02-12T17:12:31Z
# 17  /properties/163304876#/?channel=RES_LET  2025-06-13T16:43:57Z
# 18  /properties/163970885#/?channel=RES_LET  2025-06-30T15:22:57Z
# 19  /properties/163970867#/?channel=RES_LET  2025-06-30T15:22:42Z
# 20  /properties/163970870#/?channel=RES_LET  2025-06-30T15:22:45Z
# 21  /properties/161657795#/?channel=RES_LET  2025-05-08T10:23:32Z
# 22  /properties/163970783#/?channel=RES_LET  2025-06-30T15:21:23Z
# 23  /properties/161699705#/?channel=RES_LET  2025-05-08T17:34:26Z
# 24  /properties/163800473#/?channel=RES_LET  2025-06-25T17:26:47Z
#
#          addedOrReduced propertyTypeFullDescription
# 0   Added on 12/05/2025              2 bedroom flat
# 1           Added today              2 bedroom flat
# 2           Added today         1 bedroom apartment
# 3           Added today        3 bedroom maisonette
# 4           Added today              2 bedroom flat
# 5         Reduced today                 Studio flat
# 6           Added today         1 bedroom apartment
# 7           Added today            Studio apartment
# 8           Added today    1 bedroom terraced house
# 9           Added today              2 bedroom flat
# 10          Added today    1 bedroom detached house
# 11        Reduced today              1 bedroom flat
# 12        Reduced today         2 bedroom apartment
# 13          Added today         2 bedroom apartment
# 14          Added today              3 bedroom flat
# 15          Added today              1 bedroom flat
# 16        Reduced today              3 bedroom flat
# 17        Reduced today                 Studio flat
# 18          Added today              1 bedroom flat
# 19          Added today              2 bedroom flat
# 20          Added today              1 bedroom flat
# 21        Reduced today              2 bedroom flat
# 22          Added today    3 bedroom terraced house
# 23        Reduced today              1 bedroom flat
# 24        Reduced today                 Studio flat

# %%
filtered_df.to_csv("../data/properties.csv")
